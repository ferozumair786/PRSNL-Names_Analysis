# %%
import pandas as pd
from names_deconstructor import names_deconstructor

# %%
carrier_df = pd.read_csv('INSURANCE_CARRIERNAMES.csv')

# %%
names_deconstructor(carrier_df)
# Out:
# (    number_names  avg_pct_len
#  0            371        100.0
#  1            371         95.0
#  2            368         90.0
#  3            358         85.0
#  4            345         80.0
#  5            330         76.0
#  6            270         71.0
#  7            185         66.0
#  8             84         61.0
#  9             33         56.0
#  10             5         51.0
#  11             3         46.0,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1351c8b05c8>)
