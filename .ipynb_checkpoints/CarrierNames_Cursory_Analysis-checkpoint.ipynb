# %%
import pandas as pd

# %%
carrier_df = pd.read_csv('INSURANCE_CARRIERNAMES.csv')

# %%
type(carrier_df)
# Out:
# pandas.core.frame.DataFrame

# %%
carrier_df['LENGTH'] = carrier_df['COMPANYNAME'].apply(lambda x: len(x))
carrier_df['SUB_LENGTH'] = carrier_df['COMPANYNAME'].apply(lambda x: len(x))

# %%
carrier_df.head()
# Out:
#                         COMPANYNAME  LENGTH  SUB_LENGTH
# 0  1st community insurance services      32          32
# 1                      360 coverage      12          12
# 2                  360 coverage pro      16          16
# 3                 360 coverage pros      17          17
# 4                  360 coveragepros      16          16

# %%
carrier_df['PERCENT_LENGTH'] = carrier_df['LENGTH'].apply(lambda x: round(100*x/x))

# %%
carrier_df.head()
# Out:
#                         COMPANYNAME  LENGTH  SUB_LENGTH  PERCENT_LENGTH
# 0  1st community insurance services      32          32             100
# 1                      360 coverage      12          12             100
# 2                  360 coverage pro      16          16             100
# 3                 360 coverage pros      17          17             100
# 4                  360 coveragepros      16          16             100

# %%
analysis = {'number_names': [len(carrier_df['COMPANYNAME'].unique())], 'avg_pct_len': [100]}
analysis_tail = {'number_names': [len(carrier_df['COMPANYNAME'].unique())], 'avg_pct_len': [100]}
carrier_df_tail = carrier_df.copy()

# %%
analysis
# Out:
# {'number_names': [371], 'avg_pct_len': [100]}

# %%
avg_pct_min = min(analysis['avg_pct_len'])
avg_pct_min_tail = min(analysis_tail['avg_pct_len'])
substring = 1
substring_tail = 1

# %%
while avg_pct_min >= 50:

    carrier_df['COMPANYNAME'] = carrier_df['COMPANYNAME'].apply(lambda x: x[(substring):])
    carrier_df['SUB_LENGTH'] = carrier_df['LENGTH'].apply(lambda x: (x-substring))
    carrier_df['PERCENT_LENGTH'] = 100*(carrier_df['SUB_LENGTH']/carrier_df['LENGTH'])
    analysis['number_names'].append(len(carrier_df['COMPANYNAME'].unique()))
    print(carrier_df['COMPANYNAME'].unique())
    analysis['avg_pct_len'].append(round(carrier_df['PERCENT_LENGTH'].mean()))
    substring += 1
    avg_pct_min = min(analysis['avg_pct_len'])
# Out:
# ['st community insurance services' '60 coverage' '60 coverage pro'
#  '60 coverage pros' '60 coveragepros' '60 degree coverage pros'
#  'illis Fee' 'aa life insurance co.' 'aic' 'bi administrative services'
#  'ccord insurance' 'ce american insurance company' 'ce financial group'
#  'ce financial group ltd' 'cord' 'dmiral indemnity company'
#  'dmiral insurance co' 'dmiral insurance company'
#  'eon risk services northeast, inc' 'ffinity insurance service'
#  'ggressive insurance service llc' 'ggressive insurance services, llc'
#  'if- agency ins & financial' 'ig life insurance co.'
#  'ig specialty insurance company' 'jg gallager-affinity'
#  'llen & associates' 'lliant' 'llianz global risks us insurance co'
#  'llianz underwriters insurance company' 'llied world assurance ins co'
#  'llied world insurance company' 'llied world specialty insurance company'
#  'llied world surplus lines insurance'
#  'llied world surplus lines insurance company'
#  'merican administrative group (tpa)' 'merican affinity group'
#  'merican alternative insurance company'
#  'merican alternative insurance corporation' 'merican auto ins company'
#  'merican automobile insurance company' 'merican capitol insurance co.'
#  'merican endurance specialty ins co'
#  'merican family home insurance company'
#  'merican family life assurance compa'
#  'merican farmers & ranchers mutual insurance co'
#  'merican guarantee & liability'
#  'merican international specialty lines insurance c'
#  'merican national family of companies'
#  'merican national property and casualty company'
#  'merican pacific life and retirement'
#  'merican southern home insurance company'
#  'meriprise captive insurance company' 'mtrust north america' 'mwins'
#  'on affinity services' 'on risk insurance services west, inc'
#  'on risk insurance services west, inc.' 'on risk services central, inc.'
#  'on risk services northeast inc' 'on risk services northeast, inc.' 'rch'
#  'rch insurance co' 'rch speciality insurance' 'rgonaut insurance company'
#  'rthur j. gallagher - irvine' 'spen american'
#  'spen american insurance company' 'spen specialty insurance company'
#  'ssociated industries ins. co.' 'tlantic specialty insurance company'
#  'utomatic data processing insurance agency, inc' 'xis insurance company'
#  'xis surplus insurance co' 'axter and associates' 'cs insurance co'
#  'cs life insurance co.' 'eazley insurance company'
#  'enefits technologies, llc' 'erkely association services (tpa)'
#  'erkley assurance company' 'erkley insurance company'
#  'erkley service professionals, a division of berkley managers insurance services, llc'
#  'erkshire hathaway' 'erkshire hathaway insurers of biberk'
#  'erkshire hathaway speciality insurance company' 'ern insurance' 'iberk'
#  'rown & brown program insurance services, inc.' 'alsurance' 'alsurane'
#  'apitol indemnity corporation' 'apitol specialty insurance co'
#  'apitol specialty insurance corp' 'biz insurance services, inc.'
#  "ertain underwriters at lloyd's london" 'fc underwriting limited'
#  'hartis sepcialty insurance company'
#  'hartis speciality insurance company' 'hubb'
#  'hubb indemnity insurance company' 'incinnati casualty company'
#  'ita insurance carriers' 'ita lie insurance' 'ita life insurance'
#  'larendon america ins company' 'laridge insurance company' 'na'
#  'olumbia casualty insurance co' 'ontinental assurance co.'
#  'ontinental casualty company' 'ontinental casualty insurance co.'
#  'ontinental insurance co of nj' 'orrisk solutions' 'overage2care'
#  'pa mutual insurance company of america' 'aniels insurance inc.'
#  'arwin national assurance co.' 'arwin select ins co' 'efender plus/cna'
#  'iana janeth orona' 'omininion insurance services'
#  'ominion insurance services' 'onald gaddis co., inc.'
#  'ual insurance company' 'health' 'health insurance'
#  'health insurance services, inc' 'health, inc' 'health, llc'
#  'ndurance american insurance company' 'ndurance american specialty'
#  'ndurance american specialty ins co'
#  'ndurance american specialty insurance company'
#  'ndurance insurance company' 'ndurance risk solutions assurance co.'
#  'psilon insurance co' 'vanston insurance company'
#  'verest indemnity insurance company' 'verest national insurance company'
#  'xecutive risk speciality' 'cci insurance company' 'ederal insurance co'
#  'iremans fund insurance co.' 'irst choice insurance agency'
#  'irst specialty insurance corp' 'reedom insurance company'
#  'allager affinity' 'allagher affinity' 'allagher mga'
#  'eneral insurance company' 'eneral insurance company of america'
#  'raphic arts mutual insurance company' 'reat american alliance'
#  'reat american alliance insurance company'
#  'reat american asurance company' 'reat american e & s'
#  'reat american fidelity insurance company' 'reat american insurance co'
#  'reat midwest insurance' 'reat midwest life insurance co.'
#  'reenwich insurance company' 'uardian life insurance co. of america'
#  '&w indemnity (spc), ltd.' 'anover insurance group'
#  'artford insurance company' 'artford life insurance co.'
#  'cc specialty ins co' 'di specialty insurance company'
#  'iscox insurance company inc.' 'omeland insurance company'
#  'omeland insurance of new york' 'ometown insurance agency'
#  'ometown insurance of li, inc' 'ouston casualty co'
#  'ouston casualty company' 'ub international'
#  'udson specialty insurance com'
#  'cici lombard general insurance company limited'
#  'hc - specialty benefits, inc.' 'hc specailty benefits inc'
#  'hc specialty benefits' 'llinois national insurance company'
#  'llinois union insurance co' 'ndep. insurance agents of texas'
#  'ndian harbor insurance company' 'nsurancename'
#  'nsureon (bin insurance holdings llc)'
#  'nterstate fire and casualty company' 'nterweb insurance, llc'
#  'ronshore indemnity, inc.' 'ronshore specialty insurance company'
#  'ames river insurance company' 'ind health holdings inc'
#  'ind health holdings, inc' 'insale insurance co'
#  'nightbrook insurance company' 'andmark american ins. co'
#  'andmark insurance co' 'ee & mason financial services'
#  'exington insurance company' 'iberty insurance services corp. (tpa)'
#  'iberty insurance underwriters inc' 'iberty life' 'iberty mut'
#  'iberty mutual insurance co.' 'iberty surplus insurance'
#  'ighthouse insurance agency' 'incoln national life insurance co.'
#  "loyd's" "loyd's syndicate no. 1225" "loyd's syndicate no. 2623"
#  'loyds of london' 'mc insurance & risk management, inc.' 'ockton'
#  'ockton companies' 'ogic insurance services' 'oman-ray insurance group'
#  'yndon southenr insurance company' '3 insurance solutions, inc.'
#  'arkel american insurance co.' 'arkel insurance company' 'arsh'
#  'arsh & mclennan agency llc' 'arsh mclennan'
#  'arsh risk & insurance company' 'arsh risk & insurance services'
#  'arsh risk an insurance company' 'arsh risk and insurance services'
#  'arsh risk insurance services' 'assachusetts bay insurance company'
#  'axum indemnity co' 'axum insurance company' 'ercer' 'ercer consumer'
#  'ercer consumer, a service of mercer health & benefits administration llc'
#  'ercer health & benefits administation llc'
#  'ercer health & benefits administration llc'
#  'ercer health and benefits administration, llc'
#  'erchants bonding company' 'esser financial group' 'ga gallagher'
#  'ga insurance services' 'ount vernon fire insurance company' 't. vernon'
#  'aifa professional liability insurance' 'amic insurance company, inc.'
#  'apa' 'ational association of professional agents'
#  'ational association of professional agents napa'
#  'ational association of professional agents.' 'ational casualty company'
#  'ational fire & marine insurance' 'ational general accident & health'
#  'ational specialty insurance company'
#  'ational union fire ins co of pitts'
#  'ational union fire insurance company'
#  'ational union fire insurance company of'
#  'ational union fire insurance company of la' 'autilus insurance company'
#  'avigator specialty insurance' 'ew york life insurance & annuity co.'
#  'ewer test company' 'ewest test company' 'ewport insurance co, inc.'
#  'ext insurance' 'ext insurance company' 'ext insurance company/state'
#  'ext insurance inc' 'fp property & casualty services, inc.'
#  'o carrier name' 'ocarriername' 'hio national life insurance company'
#  'ld republic insurance co.' 'ther' 'acific casualty company'
#  'acific casualty company inc' 'acific indemnity company'
#  'artnerre ireland ltd' 'earl insurance' 'eleus insurance company'
#  'enn national mutual casualty' 'hiladelphia indemnity insurance co'
#  'hiladelphia insurance companies' 'ride life insurance, llc'
#  'rotective specialty insurance company' 'ug (previously uninsured group)'
#  'be insurance corporation' 'be specialty insurance company' 'uadrant'
#  'epublic franklin insurance company' 'etention alternatives ltd'
#  'isk placement services, inc.' 'ockwood programs'
#  'oyal alliance associates, inc.' 't specialty'
#  'yan turner speciality group' 'anus benefits'
#  'cottsdale indemnity company' 'cottsdale insurance co.'
#  'cottsdale surplus lines ins. co' 'ecurity national insurance company'
#  'entinel ins co ltd' 'entry life insurance co.'
#  'helter mutual insurance co' 'ompo international'
#  'outhern farm bureau life insurance company' 'rc conner group, llc'
#  't paul fire & marine ins company' 't paul guardian insurance company'
#  't paul insurance' 't. paul fire' 'tarnet insurance company'
#  'tarr indemnity and liability company'
#  'tarr surplus lines insurance company' 'tone mountain insurance company'
#  'urancebay' 'wiss re corporate solutions' 'wiss re internationall'
#  'est company' 'exas farm bureau' 'exas ins prof serv, inc' 'fa-wfg'
#  'he brokerage inc' 'he brokerage inc umbrella' 'he brokerage inc.'
#  'he brokerage will send e&o' 'he brokerage, inc' 'he brokerage, inc.'
#  'he cincinnati insurance company' 'he hanover insurance company'
#  'he ohio national life insurance company' 'he real insurance lady'
#  'he sentinel insurance company'
#  'ravelers casualty and surety company of america' 'ravelers excess'
#  'ravelers excess and surplus lines co.' 'ravelers indemnity company'
#  'win city fire insurance company' 'win city insurance company'
#  '.s. risk, llc' 'mico' "nderwriters at lloyd's london"
#  'nderwriters at lloyds' 'nited states liability insurance company'
#  'nited states liability insurance gr' 's liability insurance'
#  's risk llc' 'tica mutual insurance company' 'tica national'
#  'tica national insurance group' 'alley forge insurance' 'iti financial'
#  'esco insurance company' 'estchester surplus lines insurance'
#  'estern world' 'estern world insurance co.'
#  'estern world insurance company' 'estport insurance company'
#  'estport insurance corporation' 'fg' 'illis of new york inc'
#  'illis of new york, inc' 'illis of new york, inc.'
#  'illis submission carrier' 'orld fianancial group inc'
#  'orld financial group' 'orld financial group, inc.'
#  'orldwide brokers and agents' 'l specialty insurance co.'
#  'urich american insurance co.']
# [' community insurance services' ' coverage' ' coverage pro'
#  ' coverage pros' ' coveragepros' ' degree coverage pros' 'lis Fee'
#  ' life insurance co.' 'c' ' administrative services' 'ord insurance'
#  ' american insurance company' ' financial group' ' financial group ltd'
#  'rd' 'iral indemnity company' 'iral insurance co'
#  'iral insurance company' 'n risk services northeast, inc'
#  'inity insurance service' 'ressive insurance service llc'
#  'ressive insurance services, llc' '- agency ins & financial'
#  ' specialty insurance company' ' gallager-affinity' 'en & associates'
#  'iant' 'ianz global risks us insurance co'
#  'ianz underwriters insurance company' 'ied world assurance ins co'
#  'ied world insurance company' 'ied world specialty insurance company'
#  'ied world surplus lines insurance'
#  'ied world surplus lines insurance company'
#  'rican administrative group (tpa)' 'rican affinity group'
#  'rican alternative insurance company'
#  'rican alternative insurance corporation' 'rican auto ins company'
#  'rican automobile insurance company' 'rican capitol insurance co.'
#  'rican endurance specialty ins co' 'rican family home insurance company'
#  'rican family life assurance compa'
#  'rican farmers & ranchers mutual insurance co'
#  'rican guarantee & liability'
#  'rican international specialty lines insurance c'
#  'rican national family of companies'
#  'rican national property and casualty company'
#  'rican pacific life and retirement'
#  'rican southern home insurance company'
#  'riprise captive insurance company' 'rust north america' 'ins'
#  ' affinity services' ' risk insurance services west, inc'
#  ' risk insurance services west, inc.' ' risk services central, inc.'
#  ' risk services northeast inc' ' risk services northeast, inc.' 'h'
#  'h insurance co' 'h speciality insurance' 'onaut insurance company'
#  'hur j. gallagher - irvine' 'en american' 'en american insurance company'
#  'en specialty insurance company' 'ociated industries ins. co.'
#  'antic specialty insurance company'
#  'omatic data processing insurance agency, inc' 's insurance company'
#  's surplus insurance co' 'ter and associates' ' insurance co'
#  'zley insurance company' 'efits technologies, llc'
#  'kely association services (tpa)' 'kley assurance company'
#  'kley insurance company'
#  'kley service professionals, a division of berkley managers insurance services, llc'
#  'kshire hathaway' 'kshire hathaway insurers of biberk'
#  'kshire hathaway speciality insurance company' 'n insurance' 'erk'
#  'wn & brown program insurance services, inc.' 'surance' 'surane'
#  'itol indemnity corporation' 'itol specialty insurance co'
#  'itol specialty insurance corp' 'z insurance services, inc.'
#  "tain underwriters at lloyd's london" ' underwriting limited'
#  'rtis sepcialty insurance company' 'rtis speciality insurance company'
#  'bb' 'bb indemnity insurance company' 'cinnati casualty company'
#  'a insurance carriers' 'a lie insurance' 'a life insurance'
#  'rendon america ins company' 'ridge insurance company' ''
#  'umbia casualty insurance co' 'tinental assurance co.'
#  'tinental casualty company' 'tinental casualty insurance co.'
#  'tinental insurance co of nj' 'risk solutions' 'erage2care'
#  ' mutual insurance company of america' 'iels insurance inc.'
#  'win national assurance co.' 'win select ins co' 'ender plus/cna'
#  'na janeth orona' 'ininion insurance services' 'inion insurance services'
#  'ald gaddis co., inc.' 'l insurance company' 'alth' 'alth insurance'
#  'alth insurance services, inc' 'alth, inc' 'alth, llc'
#  'urance american insurance company' 'urance american specialty'
#  'urance american specialty ins co'
#  'urance american specialty insurance company' 'urance insurance company'
#  'urance risk solutions assurance co.' 'ilon insurance co'
#  'nston insurance company' 'rest indemnity insurance company'
#  'rest national insurance company' 'cutive risk speciality'
#  'i insurance company' 'eral insurance co' 'emans fund insurance co.'
#  'st choice insurance agency' 'st specialty insurance corp'
#  'edom insurance company' 'lager affinity' 'lagher affinity' 'lagher mga'
#  'eral insurance company' 'eral insurance company of america'
#  'phic arts mutual insurance company' 'at american alliance'
#  'at american alliance insurance company' 'at american asurance company'
#  'at american e & s' 'at american fidelity insurance company'
#  'at american insurance co' 'at midwest insurance'
#  'at midwest life insurance co.' 'enwich insurance company'
#  'rdian life insurance co. of america' ' indemnity (spc), ltd.'
#  'over insurance group' 'tford insurance company'
#  'tford life insurance co.' ' specialty ins co'
#  'cox insurance company inc.' 'eland insurance company'
#  'eland insurance of new york' 'etown insurance agency'
#  'etown insurance of li, inc' 'ston casualty co' 'ston casualty company'
#  ' international' 'son specialty insurance com'
#  'ci lombard general insurance company limited'
#  ' - specialty benefits, inc.' ' specailty benefits inc'
#  ' specialty benefits' 'inois national insurance company'
#  'inois union insurance co' 'ep. insurance agents of texas'
#  'ian harbor insurance company' 'urancename'
#  'ureon (bin insurance holdings llc)' 'erstate fire and casualty company'
#  'erweb insurance, llc' 'nshore indemnity, inc.'
#  'nshore specialty insurance company' 'es river insurance company'
#  'd health holdings inc' 'd health holdings, inc' 'sale insurance co'
#  'ghtbrook insurance company' 'dmark american ins. co'
#  'dmark insurance co' ' & mason financial services'
#  'ington insurance company' 'erty insurance services corp. (tpa)'
#  'erty insurance underwriters inc' 'erty life' 'erty mut'
#  'erty mutual insurance co.' 'erty surplus insurance'
#  'hthouse insurance agency' 'coln national life insurance co.' "yd's"
#  "yd's syndicate no. 1225" "yd's syndicate no. 2623" 'yds of london'
#  ' insurance & risk management, inc.' 'kton' 'kton companies'
#  'ic insurance services' 'an-ray insurance group'
#  'don southenr insurance company' 'insurance solutions, inc.'
#  'kel american insurance co.' 'kel insurance company' 'sh'
#  'sh & mclennan agency llc' 'sh mclennan' 'sh risk & insurance company'
#  'sh risk & insurance services' 'sh risk an insurance company'
#  'sh risk and insurance services' 'sh risk insurance services'
#  'sachusetts bay insurance company' 'um indemnity co'
#  'um insurance company' 'cer' 'cer consumer'
#  'cer consumer, a service of mercer health & benefits administration llc'
#  'cer health & benefits administation llc'
#  'cer health & benefits administration llc'
#  'cer health and benefits administration, llc' 'chants bonding company'
#  'ser financial group' ' gallagher' ' insurance services'
#  'nt vernon fire insurance company' ' vernon'
#  'fa professional liability insurance' 'ic insurance company, inc.' 'a'
#  'ional association of professional agents'
#  'ional association of professional agents napa'
#  'ional association of professional agents.' 'ional casualty company'
#  'ional fire & marine insurance' 'ional general accident & health'
#  'ional specialty insurance company' 'ional union fire ins co of pitts'
#  'ional union fire insurance company'
#  'ional union fire insurance company of'
#  'ional union fire insurance company of la' 'tilus insurance company'
#  'igator specialty insurance' ' york life insurance & annuity co.'
#  'er test company' 'est test company' 'port insurance co, inc.'
#  't insurance' 't insurance company' 't insurance company/state'
#  't insurance inc' ' property & casualty services, inc.' 'carrier name'
#  'arriername' 'o national life insurance company'
#  ' republic insurance co.' 'er' 'ific casualty company'
#  'ific casualty company inc' 'ific indemnity company' 'tnerre ireland ltd'
#  'rl insurance' 'eus insurance company' 'n national mutual casualty'
#  'ladelphia indemnity insurance co' 'ladelphia insurance companies'
#  'de life insurance, llc' 'tective specialty insurance company'
#  ' (previously uninsured group)' ' insurance corporation' 'drant'
#  'ublic franklin insurance company' 'ention alternatives ltd'
#  'k placement services, inc.' 'kwood programs'
#  'al alliance associates, inc.' 'specialty' 'n turner speciality group'
#  'us benefits' 'ttsdale indemnity company' 'ttsdale insurance co.'
#  'ttsdale surplus lines ins. co' 'urity national insurance company'
#  'tinel ins co ltd' 'try life insurance co.' 'lter mutual insurance co'
#  'po international' 'thern farm bureau life insurance company'
#  ' conner group, llc' 'paul fire & marine ins company'
#  'paul guardian insurance company' 'paul insurance' ' paul fire'
#  'rnet insurance company' 'rr indemnity and liability company'
#  'rr surplus lines insurance company' 'ne mountain insurance company'
#  'ancebay' 'ss re corporate solutions' 'ss re internationall' 't company'
#  'as farm bureau' 'as ins prof serv, inc' '-wfg' ' brokerage inc'
#  ' brokerage inc umbrella' ' brokerage inc.' ' brokerage will send e&o'
#  ' brokerage, inc' ' brokerage, inc.' ' cincinnati insurance company'
#  ' hanover insurance company' ' ohio national life insurance company'
#  ' real insurance lady' ' sentinel insurance company'
#  'velers casualty and surety company of america' 'velers excess'
#  'velers excess and surplus lines co.' 'velers indemnity company'
#  'n city fire insurance company' 'n city insurance company' '. risk, llc'
#  'co' "erwriters at lloyd's london" 'erwriters at lloyds'
#  'ted states liability insurance company'
#  'ted states liability insurance gr' 'liability insurance' 'risk llc'
#  'ca mutual insurance company' 'ca national' 'ca national insurance group'
#  'ley forge insurance' 'i financial' 'co insurance company'
#  'tchester surplus lines insurance' 'tern world'
#  'tern world insurance co.' 'tern world insurance company'
#  'tport insurance company' 'tport insurance corporation'
#  'lis of new york inc' 'lis of new york, inc' 'lis of new york, inc.'
#  'lis submission carrier' 'ld fianancial group inc' 'ld financial group'
#  'ld financial group, inc.' 'ldwide brokers and agents'
#  'specialty insurance co.' 'ich american insurance co.']
# ['mmunity insurance services' 'verage' 'verage pro' 'verage pros'
#  'veragepros' 'gree coverage pros' ' Fee' 'fe insurance co.' ''
#  'ministrative services' ' insurance' 'erican insurance company'
#  'nancial group' 'nancial group ltd' 'l indemnity company'
#  'l insurance co' 'l insurance company' 'isk services northeast, inc'
#  'ty insurance service' 'sive insurance service llc'
#  'sive insurance services, llc' 'gency ins & financial'
#  'ecialty insurance company' 'llager-affinity' '& associates' 't'
#  'z global risks us insurance co' 'z underwriters insurance company'
#  ' world assurance ins co' ' world insurance company'
#  ' world specialty insurance company' ' world surplus lines insurance'
#  ' world surplus lines insurance company' 'an administrative group (tpa)'
#  'an affinity group' 'an alternative insurance company'
#  'an alternative insurance corporation' 'an auto ins company'
#  'an automobile insurance company' 'an capitol insurance co.'
#  'an endurance specialty ins co' 'an family home insurance company'
#  'an family life assurance compa'
#  'an farmers & ranchers mutual insurance co' 'an guarantee & liability'
#  'an international specialty lines insurance c'
#  'an national family of companies'
#  'an national property and casualty company'
#  'an pacific life and retirement' 'an southern home insurance company'
#  'rise captive insurance company' 't north america' 'finity services'
#  'sk insurance services west, inc' 'sk insurance services west, inc.'
#  'sk services central, inc.' 'sk services northeast inc'
#  'sk services northeast, inc.' 'nsurance co' 'peciality insurance'
#  'ut insurance company' ' j. gallagher - irvine' 'american'
#  'american insurance company' 'specialty insurance company'
#  'ated industries ins. co.' 'ic specialty insurance company'
#  'tic data processing insurance agency, inc' 'nsurance company'
#  'urplus insurance co' ' and associates' 'surance co'
#  'y insurance company' 'ts technologies, llc'
#  'y association services (tpa)' 'y assurance company'
#  'y service professionals, a division of berkley managers insurance services, llc'
#  'ire hathaway' 'ire hathaway insurers of biberk'
#  'ire hathaway speciality insurance company' 'nsurance'
#  '& brown program insurance services, inc.' 'ance' 'ane'
#  'l indemnity corporation' 'l specialty insurance co'
#  'l specialty insurance corp' 'nsurance services, inc.'
#  "n underwriters at lloyd's london" 'derwriting limited'
#  's sepcialty insurance company' 's speciality insurance company'
#  'indemnity insurance company' 'nati casualty company' 'nsurance carriers'
#  'ie insurance' 'ife insurance' 'don america ins company'
#  'ge insurance company' 'ia casualty insurance co' 'ental assurance co.'
#  'ental casualty company' 'ental casualty insurance co.'
#  'ental insurance co of nj' 'k solutions' 'ge2care'
#  'tual insurance company of america' 's insurance inc.'
#  ' national assurance co.' ' select ins co' 'er plus/cna' 'janeth orona'
#  'nion insurance services' 'on insurance services' ' gaddis co., inc.' 'h'
#  'h insurance' 'h insurance services, inc' 'h, inc' 'h, llc'
#  'nce american insurance company' 'nce american specialty'
#  'nce american specialty ins co'
#  'nce american specialty insurance company' 'nce insurance company'
#  'nce risk solutions assurance co.' 'n insurance co'
#  'on insurance company' 't indemnity insurance company'
#  't national insurance company' 'ive risk speciality'
#  'ns fund insurance co.' 'choice insurance agency'
#  'specialty insurance corp' 'm insurance company' 'er affinity'
#  'her affinity' 'her mga' 'l insurance company of america'
#  'c arts mutual insurance company' 'american alliance'
#  'american alliance insurance company' 'american asurance company'
#  'american e & s' 'american fidelity insurance company'
#  'american insurance co' 'midwest insurance' 'midwest life insurance co.'
#  'ich insurance company' 'an life insurance co. of america'
#  'demnity (spc), ltd.' 'r insurance group' 'rd insurance company'
#  'rd life insurance co.' 'ecialty ins co' ' insurance company inc.'
#  'nd insurance company' 'nd insurance of new york' 'wn insurance agency'
#  'wn insurance of li, inc' 'n casualty co' 'n casualty company'
#  'ternational' ' specialty insurance com'
#  'lombard general insurance company limited' 'specialty benefits, inc.'
#  'ecailty benefits inc' 'ecialty benefits' 'is national insurance company'
#  'is union insurance co' ' insurance agents of texas'
#  ' harbor insurance company' 'ncename' 'on (bin insurance holdings llc)'
#  'tate fire and casualty company' 'eb insurance, llc'
#  'ore indemnity, inc.' 'ore specialty insurance company'
#  'river insurance company' 'ealth holdings inc' 'ealth holdings, inc'
#  'e insurance co' 'brook insurance company' 'rk american ins. co'
#  'rk insurance co' 'mason financial services' 'ton insurance company'
#  'y insurance services corp. (tpa)' 'y insurance underwriters inc'
#  'y life' 'y mut' 'y mutual insurance co.' 'y surplus insurance'
#  'ouse insurance agency' 'n national life insurance co.' 's'
#  's syndicate no. 1225' 's syndicate no. 2623' ' of london'
#  'surance & risk management, inc.' 'n' 'n companies' 'insurance services'
#  'ray insurance group' ' southenr insurance company'
#  'urance solutions, inc.' ' american insurance co.' ' insurance company'
#  '& mclennan agency llc' 'mclennan' 'risk & insurance company'
#  'risk & insurance services' 'risk an insurance company'
#  'risk and insurance services' 'risk insurance services'
#  'husetts bay insurance company' 'indemnity co' 'insurance company'
#  ' consumer'
#  ' consumer, a service of mercer health & benefits administration llc'
#  ' health & benefits administation llc'
#  ' health & benefits administration llc'
#  ' health and benefits administration, llc' 'nts bonding company'
#  ' financial group' 'llagher' 'surance services'
#  'vernon fire insurance company' 'rnon' 'professional liability insurance'
#  'insurance company, inc.' 'al association of professional agents'
#  'al association of professional agents napa'
#  'al association of professional agents.' 'al casualty company'
#  'al fire & marine insurance' 'al general accident & health'
#  'al specialty insurance company' 'al union fire ins co of pitts'
#  'al union fire insurance company' 'al union fire insurance company of'
#  'al union fire insurance company of la' 'us insurance company'
#  'tor specialty insurance' 'rk life insurance & annuity co.'
#  'test company' ' test company' 't insurance co, inc.'
#  'nsurance company/state' 'nsurance inc'
#  'operty & casualty services, inc.' 'rier name' 'iername'
#  'ational life insurance company' 'public insurance co.'
#  'c casualty company' 'c casualty company inc' 'c indemnity company'
#  'rre ireland ltd' 'insurance' 'ational mutual casualty'
#  'elphia indemnity insurance co' 'elphia insurance companies'
#  'life insurance, llc' 'tive specialty insurance company'
#  'reviously uninsured group)' 'surance corporation' 'nt'
#  'ic franklin insurance company' 'ion alternatives ltd'
#  'lacement services, inc.' 'od programs' 'alliance associates, inc.'
#  'cialty' 'urner speciality group' 'benefits' 'dale indemnity company'
#  'dale insurance co.' 'dale surplus lines ins. co'
#  'ty national insurance company' 'el ins co ltd' ' life insurance co.'
#  'r mutual insurance co' 'international'
#  'rn farm bureau life insurance company' 'nner group, llc'
#  'l fire & marine ins company' 'l guardian insurance company'
#  'l insurance' 'ul fire' 't insurance company'
#  'indemnity and liability company' 'surplus lines insurance company'
#  'mountain insurance company' 'ebay' 're corporate solutions'
#  're internationall' 'ompany' 'farm bureau' 'ins prof serv, inc' 'g'
#  'okerage inc' 'okerage inc umbrella' 'okerage inc.'
#  'okerage will send e&o' 'okerage, inc' 'okerage, inc.'
#  'ncinnati insurance company' 'nover insurance company'
#  'io national life insurance company' 'al insurance lady'
#  'ntinel insurance company' 'ers casualty and surety company of america'
#  'ers excess' 'ers excess and surplus lines co.' 'ers indemnity company'
#  'ity fire insurance company' 'ity insurance company' 'isk, llc'
#  "riters at lloyd's london" 'riters at lloyds'
#  ' states liability insurance company' ' states liability insurance gr'
#  'bility insurance' 'k llc' 'mutual insurance company' 'national'
#  'national insurance group' ' forge insurance' 'inancial'
#  'ester surplus lines insurance' 'n world' 'n world insurance co.'
#  'n world insurance company' 'rt insurance company'
#  'rt insurance corporation' ' of new york inc' ' of new york, inc'
#  ' of new york, inc.' ' submission carrier' 'fianancial group inc'
#  'financial group' 'financial group, inc.' 'ide brokers and agents'
#  'cialty insurance co.']
# ['ity insurance services' 'ge' 'ge pro' 'ge pros' 'gepros'
#  ' coverage pros' '' 'nsurance co.' 'strative services' 'urance'
#  'an insurance company' 'ial group' 'ial group ltd' 'demnity company'
#  'surance co' 'surance company' 'services northeast, inc'
#  'nsurance service' ' insurance service llc' ' insurance services, llc'
#  'y ins & financial' 'lty insurance company' 'er-affinity' 'sociates'
#  'obal risks us insurance co' 'derwriters insurance company'
#  'ld assurance ins co' 'ld insurance company'
#  'ld specialty insurance company' 'ld surplus lines insurance'
#  'ld surplus lines insurance company' 'dministrative group (tpa)'
#  'ffinity group' 'lternative insurance company'
#  'lternative insurance corporation' 'uto ins company'
#  'utomobile insurance company' 'apitol insurance co.'
#  'ndurance specialty ins co' 'amily home insurance company'
#  'amily life assurance compa' 'armers & ranchers mutual insurance co'
#  'uarantee & liability' 'nternational specialty lines insurance c'
#  'ational family of companies' 'ational property and casualty company'
#  'acific life and retirement' 'outhern home insurance company'
#  ' captive insurance company' 'rth america' 'ty services'
#  'nsurance services west, inc' 'nsurance services west, inc.'
#  'ervices central, inc.' 'ervices northeast inc' 'ervices northeast, inc.'
#  'ance co' 'ality insurance' 'nsurance company' 'gallagher - irvine'
#  'ican' 'ican insurance company' 'ialty insurance company'
#  ' industries ins. co.' 'pecialty insurance company'
#  'data processing insurance agency, inc' 'ance company' 'us insurance co'
#  ' associates' 'nce co' 'echnologies, llc' 'sociation services (tpa)'
#  'rvice professionals, a division of berkley managers insurance services, llc'
#  'hathaway' 'hathaway insurers of biberk'
#  'hathaway speciality insurance company' 'ance'
#  'own program insurance services, inc.' 'demnity corporation'
#  'ecialty insurance co' 'ecialty insurance corp' 'ance services, inc.'
#  "derwriters at lloyd's london" 'riting limited'
#  'pcialty insurance company' 'eciality insurance company'
#  'mnity insurance company' ' casualty company' 'ance carriers' 'nsurance'
#  'insurance' 'america ins company' 'asualty insurance co'
#  'l assurance co.' 'l casualty company' 'l casualty insurance co.'
#  'l insurance co of nj' 'lutions' 'are' ' insurance company of america'
#  'surance inc.' 'ional assurance co.' 'ect ins co' 'lus/cna' 'th orona'
#  ' insurance services' 'nsurance services' 'dis co., inc.' 'surance'
#  'surance services, inc' 'nc' 'lc' 'american insurance company'
#  'american specialty' 'american specialty ins co'
#  'american specialty insurance company' 'insurance company'
#  'risk solutions assurance co.' 'demnity insurance company'
#  'tional insurance company' 'risk speciality' 'und insurance co.'
#  'ce insurance agency' 'ialty insurance corp' 'ffinity' 'affinity' 'mga'
#  'surance company of america' 'ts mutual insurance company'
#  'ican alliance' 'ican alliance insurance company' 'ican asurance company'
#  'ican e & s' 'ican fidelity insurance company' 'ican insurance co'
#  'est insurance' 'est life insurance co.' 'ife insurance co. of america'
#  'ity (spc), ltd.' 'surance group' 'ife insurance co.' 'lty ins co'
#  'urance company inc.' 'nsurance of new york' 'nsurance agency'
#  'nsurance of li, inc' 'sualty co' 'sualty company' 'ational'
#  'cialty insurance com' 'ard general insurance company limited'
#  'ialty benefits, inc.' 'lty benefits inc' 'lty benefits'
#  'ational insurance company' 'nion insurance co' 'urance agents of texas'
#  'bor insurance company' 'ame' 'bin insurance holdings llc)'
#  ' fire and casualty company' 'nsurance, llc' 'indemnity, inc.'
#  'specialty insurance company' 'r insurance company' 'h holdings inc'
#  'h holdings, inc' 'k insurance company' 'merican ins. co' 'nsurance co'
#  'n financial services' 'surance services corp. (tpa)'
#  'surance underwriters inc' 'fe' 't' 'tual insurance co.'
#  'rplus insurance' ' insurance agency' 'tional life insurance co.'
#  'ndicate no. 1225' 'ndicate no. 2623' 'london'
#  'nce & risk management, inc.' 'mpanies' 'rance services'
#  'insurance group' 'thenr insurance company' 'ce solutions, inc.'
#  'rican insurance co.' 'urance company' 'lennan agency llc' 'nnan'
#  ' & insurance company' ' & insurance services' ' an insurance company'
#  ' and insurance services' 'tts bay insurance company' 'mnity co'
#  'rance company' 'sumer'
#  'sumer, a service of mercer health & benefits administration llc'
#  'lth & benefits administation llc' 'lth & benefits administration llc'
#  'lth and benefits administration, llc' 'bonding company' 'ancial group'
#  'her' 'nce services' 'on fire insurance company'
#  'essional liability insurance' 'rance company, inc.'
#  'ssociation of professional agents'
#  'ssociation of professional agents napa'
#  'ssociation of professional agents.' 'asualty company'
#  'ire & marine insurance' 'eneral accident & health'
#  'nion fire ins co of pitts' 'nion fire insurance company'
#  'nion fire insurance company of' 'nion fire insurance company of la'
#  'specialty insurance' 'ife insurance & annuity co.' ' company'
#  't company' 'surance co, inc.' 'ance company/state' 'ance inc'
#  'ty & casualty services, inc.' ' name' 'nal life insurance company'
#  'ic insurance co.' 'sualty company inc' 'ireland ltd' 'rance'
#  'nal mutual casualty' 'ia indemnity insurance co'
#  'ia insurance companies' ' insurance, llc' ' specialty insurance company'
#  'ously uninsured group)' 'nce corporation' 'ranklin insurance company'
#  'alternatives ltd' 'ment services, inc.' 'rograms'
#  'ance associates, inc.' 'ty' 'r speciality group' 'fits'
#  ' indemnity company' ' insurance co.' ' surplus lines ins. co'
#  'ns co ltd' 'e insurance co.' 'tual insurance co' 'rnational'
#  'arm bureau life insurance company' ' group, llc'
#  're & marine ins company' 'ardian insurance company' 'ire'
#  'mnity and liability company' 'lus lines insurance company'
#  'tain insurance company' 'orporate solutions' 'nternationall' 'ny'
#  ' bureau' 'prof serv, inc' 'age inc' 'age inc umbrella' 'age inc.'
#  'age will send e&o' 'age, inc' 'age, inc.' 'nati insurance company'
#  'ational life insurance company' 'nsurance lady' 'el insurance company'
#  'casualty and surety company of america' 'excess'
#  'excess and surplus lines co.' 'indemnity company'
#  'fire insurance company' ' llc' "rs at lloyd's london" 'rs at lloyds'
#  'tes liability insurance company' 'tes liability insurance gr'
#  'ty insurance' 'c' 'al insurance company' 'onal' 'onal insurance group'
#  'ge insurance' 'cial' 'r surplus lines insurance' 'rld'
#  'rld insurance co.' 'rld insurance company' 'nsurance corporation'
#  'new york inc' 'new york, inc' 'new york, inc.' 'mission carrier'
#  'ancial group inc' 'ncial group' 'ncial group, inc.' 'brokers and agents'
#  'ty insurance co.']
# ['nsurance services' '' 'o' 'os' 's' 'rage pros' 'nce co.' 'ive services'
#  'e' 'surance company' 'roup' 'roup ltd' 'ty company' 'ce co' 'ce company'
#  'ces northeast, inc' 'nce service' 'rance service llc'
#  'rance services, llc' ' & financial' 'nsurance company' 'finity' 'tes'
#  'risks us insurance co' 'iters insurance company' 'surance ins co'
#  'ecialty insurance company' 'rplus lines insurance'
#  'rplus lines insurance company' 'strative group (tpa)' 'ty group'
#  'ative insurance company' 'ative insurance corporation' 'ns company'
#  'bile insurance company' 'l insurance co.' 'nce specialty ins co'
#  ' home insurance company' ' life assurance compa'
#  's & ranchers mutual insurance co' 'tee & liability'
#  'ational specialty lines insurance c' 'al family of companies'
#  'al property and casualty company' 'c life and retirement'
#  'rn home insurance company' 'ive insurance company' 'merica' 'rvices'
#  'nce services west, inc' 'nce services west, inc.' 'es central, inc.'
#  'es northeast inc' 'es northeast, inc.' 'co' ' insurance' 'nce company'
#  'gher - irvine' 'insurance company' ' insurance company'
#  'stries ins. co.' 'lty insurance company'
#  'processing insurance agency, inc' 'company' 'surance co' 'ciates'
#  'logies, llc' 'tion services (tpa)'
#  ' professionals, a division of berkley managers insurance services, llc'
#  'way' 'way insurers of biberk' 'way speciality insurance company'
#  'rogram insurance services, inc.' 'ty corporation' 'ty insurance co'
#  'ty insurance corp' 'services, inc.' "iters at lloyd's london"
#  'g limited' 'ty insurance company' 'ity insurance company' 'alty company'
#  'carriers' 'nce' 'ance' 'ca ins company' 'urance co.' 'ualty company'
#  'ualty insurance co.' 'urance co of nj' 'ns' 'rance company of america'
#  'ce inc.' ' assurance co.' 'ns co' 'na' 'ona' 'rance services'
#  'nce services' 'o., inc.' 'ce' 'ce services, inc' 'can insurance company'
#  'can specialty' 'can specialty ins co' 'can specialty insurance company'
#  'ance company' 'solutions assurance co.' 'l insurance company'
#  'speciality' 'nsurance co.' 'surance agency' ' insurance corp' 'ty' 'ity'
#  'ce company of america' 'tual insurance company' 'alliance'
#  'alliance insurance company' 'asurance company' 'e & s'
#  'fidelity insurance company' 'insurance co' 'nsurance'
#  'ife insurance co.' 'nsurance co. of america' 'spc), ltd.' 'ce group'
#  'e company inc.' 'nce of new york' 'nce agency' 'nce of li, inc' 'y co'
#  'y company' 'al' 'y insurance com' 'eneral insurance company limited'
#  ' benefits, inc.' 'enefits inc' 'enefits' 'al insurance company'
#  'e agents of texas' 'nsurance holdings llc)' ' and casualty company'
#  'nce, llc' 'nity, inc.' 'alty insurance company' 'urance company'
#  'dings inc' 'dings, inc' 'an ins. co' 'nce co' 'ancial services'
#  'ce services corp. (tpa)' 'ce underwriters inc' 'insurance co.'
#  'rance agency' 'l life insurance co.' 'te no. 1225' 'te no. 2623' 'n'
#  ' risk management, inc.' 'es' ' services' 'ance group' 'lutions, inc.'
#  ' insurance co.' 'e company' 'n agency llc' 'surance services'
#  'insurance services' 'ay insurance company' ' co' ' company'
#  ', a service of mercer health & benefits administration llc'
#  ' benefits administation llc' ' benefits administration llc'
#  'nd benefits administration, llc' 'ng company' 'l group' 'ervices'
#  're insurance company' 'nal liability insurance' ' company, inc.'
#  'ation of professional agents' 'ation of professional agents napa'
#  'ation of professional agents.' ' marine insurance' 'l accident & health'
#  'fire ins co of pitts' 'fire insurance company'
#  'fire insurance company of' 'fire insurance company of la'
#  'alty insurance' 'nsurance & annuity co.' 'any' 'pany' 'ce co, inc.'
#  'company/state' 'inc' 'casualty services, inc.' 'ife insurance company'
#  'surance co.' 'y company inc' 'nd ltd' 'utual casualty'
#  'demnity insurance co' 'surance companies' 'rance, llc'
#  'ialty insurance company' ' uninsured group)' 'orporation'
#  'in insurance company' 'natives ltd' 'ms' 'associates, inc.'
#  'ciality group' 'mnity company' 'rance co.' 'lus lines ins. co' ' ltd'
#  'onal' 'ureau life insurance company' 'p, llc' 'marine ins company'
#  'n insurance company' ' and liability company' 'ines insurance company'
#  'ate solutions' 'ationall' 'au' 'serv, inc' 'nc' 'nc umbrella' 'nc.'
#  'ill send e&o' 'inc.' 'al life insurance company' 'nce lady'
#  'lty and surety company of america' 's and surplus lines co.'
#  'nity company' " lloyd's london" ' lloyds' 'iability insurance company'
#  'iability insurance gr' 'surance' 'insurance group'
#  'plus lines insurance' 'nce corporation' 'ork inc' 'ork, inc' 'ork, inc.'
#  'on carrier' 'l group inc' ' group' ' group, inc.' 'rs and agents']
# ['ce services' '' 'ros' '.' 'rvices' 'e company' 'td' 'pany'
#  'rtheast, inc' 'rvice' 'service llc' 'services, llc' 'ancial'
#  'ce company' 'us insurance co' 'insurance company' 'e ins co'
#  'y insurance company' 'lines insurance' 'lines insurance company'
#  've group (tpa)' 'up' 'insurance corporation' 'nsurance company'
#  'rance co.' 'ecialty ins co' 'assurance compa'
#  'nchers mutual insurance co' 'liability' 'l specialty lines insurance c'
#  'ily of companies' 'perty and casualty company' ' and retirement'
#  'e insurance company' 'surance company' 'rvices west, inc'
#  'rvices west, inc.' 'tral, inc.' 'theast inc' 'theast, inc.' 'ance'
#  'mpany' ' irvine' 'nce company' 'ance company' ' ins. co.'
#  'sing insurance agency, inc' 'y' 'e co' ', llc' 'ervices (tpa)'
#  'ssionals, a division of berkley managers insurance services, llc'
#  'surers of biberk' 'eciality insurance company'
#  ' insurance services, inc.' 'poration' 'urance co' 'urance corp'
#  'es, inc.' "at lloyd's london" 'ted' 'urance company' 'ompany' 'rs'
#  ' company' ' co.' 'company' 'insurance co.' ' co of nj'
#  'company of america' 'ance co.' 'services' 'c.' 'vices, inc' 'ecialty'
#  'ecialty insurance company' 'ons assurance co.' 'rance company' 'lity'
#  'ce co.' 'e agency' 'ance corp' 'pany of america' 'ce'
#  'ce insurance company' 'ty insurance company' 'nce co' 'surance co.'
#  'ce co. of america' 'ltd.' 'any inc.' ' new york' 'ency' ' li, inc' 'any'
#  'rance com' ' insurance company limited' 'its, inc.' 's inc' 's'
#  'ts of texas' 'ce holdings llc)' 'asualty company' 'lc' 'inc.' 'inc'
#  ' inc' '. co' ' services' 'vices corp. (tpa)' 'erwriters inc' 'nce co.'
#  'agency' ' insurance co.' ' 1225' ' 2623' 'management, inc.' 'ces' 'roup'
#  's, inc.' 'cy llc' 'e services' 'nce services' 'ny'
#  'rvice of mercer health & benefits administration llc'
#  'its administation llc' 'its administration llc'
#  'efits administration, llc' 'p' 'ability insurance' 'ny, inc.'
#  'of professional agents' 'of professional agents napa'
#  'of professional agents.' 'e insurance' 'dent & health' 'ns co of pitts'
#  'nsurance company of' 'nsurance company of la' 'nsurance'
#  'ce & annuity co.' ' inc.' 'y/state' 'ty services, inc.' 'e co.'
#  'any inc' 'casualty' 'y insurance co' 'e companies' ' llc' 'ured group)'
#  'tion' 's ltd' 'ates, inc.' 'y group' 'co.' 'nes ins. co'
#  'life insurance company' ' ins company' 'iability company' 'lutions' 'll'
#  'rella' 'nd e&o' 'dy' 'd surety company of america' 'surplus lines co.'
#  "'s london" 'ty insurance gr' 'e' 'nce group' 'ines insurance'
#  'rporation' 'c' 'nc' 'nc.' 'rier' 'p inc' ', inc.' ' agents']
# ['ices' '' 'ny' ', inc' ' llc' 's, llc' 'any' 'rance co' 'ce company' 'o'
#  'ance company' 'nsurance' 'nsurance company' 'p (tpa)' 'ce corporation'
#  'e company' 'o.' ' ins co' 'ce compa' 'mutual insurance co' 'ty'
#  'alty lines insurance c' 'companies' 'nd casualty company' 'tirement'
#  ' company' 'west, inc' 'west, inc.' 'nc.' 'inc' ' inc.' 'pany' 'mpany'
#  'surance agency, inc' ' (tpa)'
#  's, a division of berkley managers insurance services, llc' 'of biberk'
#  'y insurance company' 'nce services, inc.' 'n' 'co' 'corp' '.'
#  "d's london" 'company' 'y' 'ce co.' 'nj' ' of america' 's'
#  ' insurance company' 'urance co.' 'ompany' 'rp' ' america'
#  'rance company' ' co.' 'of america' 'rk' 'c' 'om' 'nce company limited'
#  'c.' 'exas' 'ings llc)' 'es' 'orp. (tpa)' 'rs inc' 'nce co.' 'ent, inc.'
#  'ces' 'vices' 'f mercer health & benefits administration llc'
#  'inistation llc' 'inistration llc' 'dministration, llc' ' insurance'
#  'essional agents' 'essional agents napa' 'essional agents.' 'ance'
#  'health' 'f pitts' 'e company of' 'e company of la' 'e' 'nuity co.'
#  'ices, inc.' 'ance co' 'nies' 'oup)' '. co' 'surance company' 'y company'
#  'y company of america' ' lines co.' 'on' 'rance gr' 'up' 'surance']
# ['' 'ny' 'pany' ' company' 'ration' 'y' 'nsurance co' 'es insurance c' 's'
#  'lty company' 'c' 'c.' 'agency, inc'
#  'ision of berkley managers insurance services, llc' 'k' 'nce company'
#  'ices, inc.' 'on' 'ica' 'ce company' 'o.' 'mpany' 'ca' 'any limited' ')'
#  'a)' '.' ' health & benefits administration llc' 'on llc' 'ion llc'
#  'ation, llc' 'ce' ' agents' ' agents napa' ' agents.' 'y of' 'y of la'
#  'company' 'y of america']
# ['' 'co' 'nce c' 'ny' 'nc' 'berkley managers insurance services, llc' '.'
#  'y' 'ed' ' benefits administration llc' 'c' 'apa' 'ica']
# ['' 'nagers insurance services, llc' 'administration llc']
# ['' 'rance services, llc' 'ion llc']

# %%
# carrier_df

# %%
analysis
# Out:
# {'number_names': [371, 371, 366, 345, 311, 258, 180, 100, 39, 13, 3, 3],
#  'avg_pct_len': [100,
#   95.0,
#   90.0,
#   85.0,
#   80.0,
#   76.0,
#   71.0,
#   66.0,
#   61.0,
#   56.0,
#   51.0,
#   46.0]}

# %%
analysis_df = pd.DataFrame(analysis)

# %%
analysis_df
# Out:
#     number_names  avg_pct_len
# 0            371        100.0
# 1            371         95.0
# 2            366         90.0
# 3            345         85.0
# 4            311         80.0
# 5            258         76.0
# 6            180         71.0
# 7            100         66.0
# 8             39         61.0
# 9             13         56.0
# 10             3         51.0
# 11             3         46.0

# %%
import matplotlib

# %%
analysis_df.plot(x='avg_pct_len', y='number_names')

# %%
while avg_pct_min_tail >= 50:

    carrier_df_tail['COMPANYNAME'] = carrier_df_tail['COMPANYNAME'].apply(lambda x: x[:len(x)-(substring_tail)])
    carrier_df_tail['SUB_LENGTH'] = carrier_df_tail['LENGTH'].apply(lambda x: (x-substring_tail))
    carrier_df_tail['PERCENT_LENGTH'] = 100*(carrier_df_tail['SUB_LENGTH']/carrier_df_tail['LENGTH'])
    analysis_tail['number_names'].append(len(carrier_df_tail['COMPANYNAME'].unique()))
    print(carrier_df_tail['COMPANYNAME'].unique())
    analysis_tail['avg_pct_len'].append(round(carrier_df_tail['PERCENT_LENGTH'].mean()))
    substring_tail += 1
    avg_pct_min_tail = min(analysis_tail['avg_pct_len'])
# Out:
# ['1st community insurance service' '360 coverag' '360 coverage pr'
#  '360 coverage pro' '360 coveragepro' '360 degree coverage pro'
#  'Willis Fe' 'aaa life insurance co' 'aai' 'abi administrative service'
#  'accord insuranc' 'ace american insurance compan' 'ace financial grou'
#  'ace financial group lt' 'acor' 'admiral indemnity compan'
#  'admiral insurance c' 'admiral insurance compan'
#  'aeon risk services northeast, in' 'affinity insurance servic'
#  'aggressive insurance service ll' 'aggressive insurance services, ll'
#  'aif- agency ins & financia' 'aig life insurance co'
#  'aig specialty insurance compan' 'ajg gallager-affinit'
#  'allen & associate' 'allian' 'allianz global risks us insurance c'
#  'allianz underwriters insurance compan' 'allied world assurance ins c'
#  'allied world insurance compan' 'allied world specialty insurance compan'
#  'allied world surplus lines insuranc'
#  'allied world surplus lines insurance compan'
#  'american administrative group (tpa' 'american affinity grou'
#  'american alternative insurance compan'
#  'american alternative insurance corporatio' 'american auto ins compan'
#  'american automobile insurance compan' 'american capitol insurance co'
#  'american endurance specialty ins c'
#  'american family home insurance compan'
#  'american family life assurance comp'
#  'american farmers & ranchers mutual insurance c'
#  'american guarantee & liabilit'
#  'american international specialty lines insurance '
#  'american national family of companie'
#  'american national property and casualty compan'
#  'american pacific life and retiremen'
#  'american southern home insurance compan'
#  'ameriprise captive insurance compan' 'amtrust north americ' 'amwin'
#  'aon affinity service' 'aon risk insurance services west, in'
#  'aon risk insurance services west, inc' 'aon risk services central, inc'
#  'aon risk services northeast in' 'aon risk services northeast, inc' 'arc'
#  'arch insurance c' 'arch speciality insuranc' 'argonaut insurance compan'
#  'arthur j. gallagher - irvin' 'aspen america'
#  'aspen american insurance compan' 'aspen specialty insurance compan'
#  'associated industries ins. co' 'atlantic specialty insurance compan'
#  'automatic data processing insurance agency, in' 'axis insurance compan'
#  'axis surplus insurance c' 'baxter and associate' 'bcs insurance c'
#  'bcs life insurance co' 'beazley insurance compan'
#  'benefits technologies, ll' 'berkely association services (tpa'
#  'berkley assurance compan' 'berkley insurance compan'
#  'berkley service professionals, a division of berkley managers insurance services, ll'
#  'berkshire hathawa' 'berkshire hathaway insurers of biber'
#  'berkshire hathaway speciality insurance compan' 'bern insuranc' 'biber'
#  'brown & brown program insurance services, inc' 'calsuranc' 'calsuran'
#  'capitol indemnity corporatio' 'capitol specialty insurance c'
#  'capitol specialty insurance cor' 'cbiz insurance services, inc'
#  "certain underwriters at lloyd's londo" 'cfc underwriting limite'
#  'chartis sepcialty insurance compan'
#  'chartis speciality insurance compan' 'chub'
#  'chubb indemnity insurance compan' 'cincinnati casualty compan'
#  'cita insurance carrier' 'cita lie insuranc' 'cita life insuranc'
#  'clarendon america ins compan' 'claridge insurance compan' 'cn'
#  'columbia casualty insurance c' 'continental assurance co'
#  'continental casualty compan' 'continental casualty insurance co'
#  'continental insurance co of n' 'corrisk solution' 'coverage2car'
#  'cpa mutual insurance company of americ' 'daniels insurance inc'
#  'darwin national assurance co' 'darwin select ins c' 'defender plus/cn'
#  'diana janeth oron' 'domininion insurance service'
#  'dominion insurance service' 'donald gaddis co., inc'
#  'dual insurance compan' 'ehealt' 'ehealth insuranc'
#  'ehealth insurance services, in' 'ehealth, in' 'ehealth, ll'
#  'endurance american insurance compan' 'endurance american specialt'
#  'endurance american specialty ins c'
#  'endurance american specialty insurance compan'
#  'endurance insurance compan' 'endurance risk solutions assurance co'
#  'epsilon insurance c' 'evanston insurance compan'
#  'everest indemnity insurance compan' 'everest national insurance compan'
#  'executive risk specialit' 'fcci insurance compan' 'federal insurance c'
#  'firemans fund insurance co' 'first choice insurance agenc'
#  'first specialty insurance cor' 'freedom insurance compan'
#  'gallager affinit' 'gallagher affinit' 'gallagher mg'
#  'general insurance compan' 'general insurance company of americ'
#  'graphic arts mutual insurance compan' 'great american allianc'
#  'great american alliance insurance compan'
#  'great american asurance compan' 'great american e & '
#  'great american fidelity insurance compan' 'great american insurance c'
#  'great midwest insuranc' 'great midwest life insurance co'
#  'greenwich insurance compan' 'guardian life insurance co. of americ'
#  'h&w indemnity (spc), ltd' 'hanover insurance grou'
#  'hartford insurance compan' 'hartford life insurance co'
#  'hcc specialty ins c' 'hdi specialty insurance compan'
#  'hiscox insurance company inc' 'homeland insurance compan'
#  'homeland insurance of new yor' 'hometown insurance agenc'
#  'hometown insurance of li, in' 'houston casualty c'
#  'houston casualty compan' 'hub internationa'
#  'hudson specialty insurance co'
#  'icici lombard general insurance company limite'
#  'ihc - specialty benefits, inc' 'ihc specailty benefits in'
#  'ihc specialty benefit' 'illinois national insurance compan'
#  'illinois union insurance c' 'indep. insurance agents of texa'
#  'indian harbor insurance compan' 'insurancenam'
#  'insureon (bin insurance holdings llc'
#  'interstate fire and casualty compan' 'interweb insurance, ll'
#  'ironshore indemnity, inc' 'ironshore specialty insurance compan'
#  'james river insurance compan' 'kind health holdings in'
#  'kind health holdings, in' 'kinsale insurance c'
#  'knightbrook insurance compan' 'landmark american ins. c'
#  'landmark insurance c' 'lee & mason financial service'
#  'lexington insurance compan' 'liberty insurance services corp. (tpa'
#  'liberty insurance underwriters in' 'liberty lif' 'liberty mu'
#  'liberty mutual insurance co' 'liberty surplus insuranc'
#  'lighthouse insurance agenc' 'lincoln national life insurance co'
#  "lloyd'" "lloyd's syndicate no. 122" "lloyd's syndicate no. 262"
#  'lloyds of londo' 'lmc insurance & risk management, inc' 'lockto'
#  'lockton companie' 'logic insurance service' 'loman-ray insurance grou'
#  'lyndon southenr insurance compan' 'm3 insurance solutions, inc'
#  'markel american insurance co' 'markel insurance compan' 'mars'
#  'marsh & mclennan agency ll' 'marsh mclenna'
#  'marsh risk & insurance compan' 'marsh risk & insurance service'
#  'marsh risk an insurance compan' 'marsh risk and insurance service'
#  'marsh risk insurance service' 'massachusetts bay insurance compan'
#  'maxum indemnity c' 'maxum insurance compan' 'merce' 'mercer consume'
#  'mercer consumer, a service of mercer health & benefits administration ll'
#  'mercer health & benefits administation ll'
#  'mercer health & benefits administration ll'
#  'mercer health and benefits administration, ll'
#  'merchants bonding compan' 'messer financial grou' 'mga gallaghe'
#  'mga insurance service' 'mount vernon fire insurance compan' 'mt. verno'
#  'naifa professional liability insuranc' 'namic insurance company, inc'
#  'nap' 'national association of professional agent'
#  'national association of professional agents nap'
#  'national association of professional agents' 'national casualty compan'
#  'national fire & marine insuranc' 'national general accident & healt'
#  'national specialty insurance compan'
#  'national union fire ins co of pitt'
#  'national union fire insurance compan'
#  'national union fire insurance company o'
#  'national union fire insurance company of l' 'nautilus insurance compan'
#  'navigator specialty insuranc' 'new york life insurance & annuity co'
#  'newer test compan' 'newest test compan' 'newport insurance co, inc'
#  'next insuranc' 'next insurance compan' 'next insurance company/stat'
#  'next insurance in' 'nfp property & casualty services, inc'
#  'no carrier nam' 'nocarriernam' 'ohio national life insurance compan'
#  'old republic insurance co' 'othe' 'pacific casualty compan'
#  'pacific casualty company in' 'pacific indemnity compan'
#  'partnerre ireland lt' 'pearl insuranc' 'peleus insurance compan'
#  'penn national mutual casualt' 'philadelphia indemnity insurance c'
#  'philadelphia insurance companie' 'pride life insurance, ll'
#  'protective specialty insurance compan' 'pug (previously uninsured group'
#  'qbe insurance corporatio' 'qbe specialty insurance compan' 'quadran'
#  'republic franklin insurance compan' 'retention alternatives lt'
#  'risk placement services, inc' 'rockwood program'
#  'royal alliance associates, inc' 'rt specialt'
#  'ryan turner speciality grou' 'sanus benefit'
#  'scottsdale indemnity compan' 'scottsdale insurance co'
#  'scottsdale surplus lines ins. c' 'security national insurance compan'
#  'sentinel ins co lt' 'sentry life insurance co'
#  'shelter mutual insurance c' 'sompo internationa'
#  'southern farm bureau life insurance compan' 'src conner group, ll'
#  'st paul fire & marine ins compan' 'st paul guardian insurance compan'
#  'st paul insuranc' 'st. paul fir' 'starnet insurance compan'
#  'starr indemnity and liability compan'
#  'starr surplus lines insurance compan' 'stone mountain insurance compan'
#  'suranceba' 'swiss re corporate solution' 'swiss re international'
#  'test compan' 'texas farm burea' 'texas ins prof serv, in' 'tfa-wf'
#  'the brokerage in' 'the brokerage inc umbrell' 'the brokerage inc'
#  'the brokerage will send e&' 'the brokerage, in' 'the brokerage, inc'
#  'the cincinnati insurance compan' 'the hanover insurance compan'
#  'the ohio national life insurance compan' 'the real insurance lad'
#  'the sentinel insurance compan'
#  'travelers casualty and surety company of americ' 'travelers exces'
#  'travelers excess and surplus lines co' 'travelers indemnity compan'
#  'twin city fire insurance compan' 'twin city insurance compan'
#  'u.s. risk, ll' 'umic' "underwriters at lloyd's londo"
#  'underwriters at lloyd' 'united states liability insurance compan'
#  'united states liability insurance g' 'us liability insuranc'
#  'us risk ll' 'utica mutual insurance compan' 'utica nationa'
#  'utica national insurance grou' 'valley forge insuranc' 'viti financia'
#  'wesco insurance compan' 'westchester surplus lines insuranc'
#  'western worl' 'western world insurance co'
#  'western world insurance compan' 'westport insurance compan'
#  'westport insurance corporatio' 'wf' 'willis of new york in'
#  'willis of new york, in' 'willis of new york, inc'
#  'willis submission carrie' 'world fianancial group in'
#  'world financial grou' 'world financial group, inc'
#  'worldwide brokers and agent' 'xl specialty insurance co'
#  'zurich american insurance co']
# ['1st community insurance servi' '360 cover' '360 coverage '
#  '360 coverage p' '360 coveragep' '360 degree coverage p' 'Willis '
#  'aaa life insurance ' 'a' 'abi administrative servi' 'accord insura'
#  'ace american insurance comp' 'ace financial gr' 'ace financial group '
#  'ac' 'admiral indemnity comp' 'admiral insurance'
#  'admiral insurance comp' 'aeon risk services northeast, '
#  'affinity insurance serv' 'aggressive insurance service '
#  'aggressive insurance services, ' 'aif- agency ins & financ'
#  'aig life insurance ' 'aig specialty insurance comp' 'ajg gallager-affin'
#  'allen & associa' 'alli' 'allianz global risks us insurance'
#  'allianz underwriters insurance comp' 'allied world assurance ins'
#  'allied world insurance comp' 'allied world specialty insurance comp'
#  'allied world surplus lines insura'
#  'allied world surplus lines insurance comp'
#  'american administrative group (t' 'american affinity gr'
#  'american alternative insurance comp'
#  'american alternative insurance corporat' 'american auto ins comp'
#  'american automobile insurance comp' 'american capitol insurance '
#  'american endurance specialty ins' 'american family home insurance comp'
#  'american family life assurance co'
#  'american farmers & ranchers mutual insurance'
#  'american guarantee & liabil'
#  'american international specialty lines insuranc'
#  'american national family of compan'
#  'american national property and casualty comp'
#  'american pacific life and retirem'
#  'american southern home insurance comp'
#  'ameriprise captive insurance comp' 'amtrust north amer' 'amw'
#  'aon affinity servi' 'aon risk insurance services west, '
#  'aon risk insurance services west, i' 'aon risk services central, i'
#  'aon risk services northeast ' 'aon risk services northeast, i'
#  'arch insurance' 'arch speciality insura' 'argonaut insurance comp'
#  'arthur j. gallagher - irv' 'aspen ameri' 'aspen american insurance comp'
#  'aspen specialty insurance comp' 'associated industries ins. '
#  'atlantic specialty insurance comp'
#  'automatic data processing insurance agency, ' 'axis insurance comp'
#  'axis surplus insurance' 'baxter and associa' 'bcs insurance'
#  'bcs life insurance ' 'beazley insurance comp' 'benefits technologies, '
#  'berkely association services (t' 'berkley assurance comp'
#  'berkley insurance comp'
#  'berkley service professionals, a division of berkley managers insurance services, '
#  'berkshire hatha' 'berkshire hathaway insurers of bib'
#  'berkshire hathaway speciality insurance comp' 'bern insura' 'bib'
#  'brown & brown program insurance services, i' 'calsura' 'calsur'
#  'capitol indemnity corporat' 'capitol specialty insurance'
#  'capitol specialty insurance c' 'cbiz insurance services, i'
#  "certain underwriters at lloyd's lon" 'cfc underwriting limi'
#  'chartis sepcialty insurance comp' 'chartis speciality insurance comp'
#  'ch' 'chubb indemnity insurance comp' 'cincinnati casualty comp'
#  'cita insurance carri' 'cita lie insura' 'cita life insura'
#  'clarendon america ins comp' 'claridge insurance comp' ''
#  'columbia casualty insurance' 'continental assurance '
#  'continental casualty comp' 'continental casualty insurance '
#  'continental insurance co of' 'corrisk soluti' 'coverage2c'
#  'cpa mutual insurance company of amer' 'daniels insurance i'
#  'darwin national assurance ' 'darwin select ins' 'defender plus/'
#  'diana janeth or' 'domininion insurance servi' 'dominion insurance servi'
#  'donald gaddis co., i' 'dual insurance comp' 'ehea' 'ehealth insura'
#  'ehealth insurance services, ' 'ehealth, '
#  'endurance american insurance comp' 'endurance american specia'
#  'endurance american specialty ins'
#  'endurance american specialty insurance comp' 'endurance insurance comp'
#  'endurance risk solutions assurance ' 'epsilon insurance'
#  'evanston insurance comp' 'everest indemnity insurance comp'
#  'everest national insurance comp' 'executive risk special'
#  'fcci insurance comp' 'federal insurance' 'firemans fund insurance '
#  'first choice insurance age' 'first specialty insurance c'
#  'freedom insurance comp' 'gallager affin' 'gallagher affin' 'gallagher '
#  'general insurance comp' 'general insurance company of amer'
#  'graphic arts mutual insurance comp' 'great american allia'
#  'great american alliance insurance comp' 'great american asurance comp'
#  'great american e ' 'great american fidelity insurance comp'
#  'great american insurance' 'great midwest insura'
#  'great midwest life insurance ' 'greenwich insurance comp'
#  'guardian life insurance co. of amer' 'h&w indemnity (spc), l'
#  'hanover insurance gr' 'hartford insurance comp'
#  'hartford life insurance ' 'hcc specialty ins'
#  'hdi specialty insurance comp' 'hiscox insurance company i'
#  'homeland insurance comp' 'homeland insurance of new y'
#  'hometown insurance age' 'hometown insurance of li, ' 'houston casualty'
#  'houston casualty comp' 'hub internatio' 'hudson specialty insurance '
#  'icici lombard general insurance company limi'
#  'ihc - specialty benefits, i' 'ihc specailty benefits '
#  'ihc specialty benef' 'illinois national insurance comp'
#  'illinois union insurance' 'indep. insurance agents of te'
#  'indian harbor insurance comp' 'insurancen'
#  'insureon (bin insurance holdings l' 'interstate fire and casualty comp'
#  'interweb insurance, ' 'ironshore indemnity, i'
#  'ironshore specialty insurance comp' 'james river insurance comp'
#  'kind health holdings ' 'kind health holdings, ' 'kinsale insurance'
#  'knightbrook insurance comp' 'landmark american ins.'
#  'landmark insurance' 'lee & mason financial servi'
#  'lexington insurance comp' 'liberty insurance services corp. (t'
#  'liberty insurance underwriters ' 'liberty l' 'liberty '
#  'liberty mutual insurance ' 'liberty surplus insura'
#  'lighthouse insurance age' 'lincoln national life insurance ' 'lloy'
#  "lloyd's syndicate no. 1" "lloyd's syndicate no. 2" 'lloyds of lon'
#  'lmc insurance & risk management, i' 'lock' 'lockton compan'
#  'logic insurance servi' 'loman-ray insurance gr'
#  'lyndon southenr insurance comp' 'm3 insurance solutions, i'
#  'markel american insurance ' 'markel insurance comp' 'ma'
#  'marsh & mclennan agency ' 'marsh mclen' 'marsh risk & insurance comp'
#  'marsh risk & insurance servi' 'marsh risk an insurance comp'
#  'marsh risk and insurance servi' 'marsh risk insurance servi'
#  'massachusetts bay insurance comp' 'maxum indemnity'
#  'maxum insurance comp' 'mer' 'mercer consu'
#  'mercer consumer, a service of mercer health & benefits administration '
#  'mercer health & benefits administation '
#  'mercer health & benefits administration '
#  'mercer health and benefits administration, ' 'merchants bonding comp'
#  'messer financial gr' 'mga gallag' 'mga insurance servi'
#  'mount vernon fire insurance comp' 'mt. ver'
#  'naifa professional liability insura' 'namic insurance company, i' 'n'
#  'national association of professional age'
#  'national association of professional agents n'
#  'national association of professional agen' 'national casualty comp'
#  'national fire & marine insura' 'national general accident & hea'
#  'national specialty insurance comp' 'national union fire ins co of pi'
#  'national union fire insurance comp'
#  'national union fire insurance company'
#  'national union fire insurance company of' 'nautilus insurance comp'
#  'navigator specialty insura' 'new york life insurance & annuity '
#  'newer test comp' 'newest test comp' 'newport insurance co, i'
#  'next insura' 'next insurance comp' 'next insurance company/st'
#  'next insurance ' 'nfp property & casualty services, i' 'no carrier n'
#  'nocarriern' 'ohio national life insurance comp'
#  'old republic insurance ' 'ot' 'pacific casualty comp'
#  'pacific casualty company ' 'pacific indemnity comp' 'partnerre ireland '
#  'pearl insura' 'peleus insurance comp' 'penn national mutual casua'
#  'philadelphia indemnity insurance' 'philadelphia insurance compan'
#  'pride life insurance, ' 'protective specialty insurance comp'
#  'pug (previously uninsured gro' 'qbe insurance corporat'
#  'qbe specialty insurance comp' 'quadr' 'republic franklin insurance comp'
#  'retention alternatives ' 'risk placement services, i' 'rockwood progr'
#  'royal alliance associates, i' 'rt specia' 'ryan turner speciality gr'
#  'sanus benef' 'scottsdale indemnity comp' 'scottsdale insurance '
#  'scottsdale surplus lines ins.' 'security national insurance comp'
#  'sentinel ins co ' 'sentry life insurance ' 'shelter mutual insurance'
#  'sompo internatio' 'southern farm bureau life insurance comp'
#  'src conner group, ' 'st paul fire & marine ins comp'
#  'st paul guardian insurance comp' 'st paul insura' 'st. paul f'
#  'starnet insurance comp' 'starr indemnity and liability comp'
#  'starr surplus lines insurance comp' 'stone mountain insurance comp'
#  'surance' 'swiss re corporate soluti' 'swiss re internation' 'test comp'
#  'texas farm bur' 'texas ins prof serv, ' 'tfa-' 'the brokerage '
#  'the brokerage inc umbre' 'the brokerage i' 'the brokerage will send '
#  'the brokerage, ' 'the brokerage, i' 'the cincinnati insurance comp'
#  'the hanover insurance comp' 'the ohio national life insurance comp'
#  'the real insurance l' 'the sentinel insurance comp'
#  'travelers casualty and surety company of amer' 'travelers exc'
#  'travelers excess and surplus lines ' 'travelers indemnity comp'
#  'twin city fire insurance comp' 'twin city insurance comp' 'u.s. risk, '
#  'um' "underwriters at lloyd's lon" 'underwriters at llo'
#  'united states liability insurance comp'
#  'united states liability insurance' 'us liability insura' 'us risk '
#  'utica mutual insurance comp' 'utica natio' 'utica national insurance gr'
#  'valley forge insura' 'viti financ' 'wesco insurance comp'
#  'westchester surplus lines insura' 'western wo'
#  'western world insurance ' 'western world insurance comp'
#  'westport insurance comp' 'westport insurance corporat'
#  'willis of new york ' 'willis of new york, ' 'willis of new york, i'
#  'willis submission carr' 'world fianancial group ' 'world financial gr'
#  'world financial group, i' 'worldwide brokers and age'
#  'xl specialty insurance ' 'zurich american insurance ']
# ['1st community insurance se' '360 co' '360 covera' '360 coverag'
#  '360 degree coverag' 'Will' 'aaa life insuran' '' 'abi administrative se'
#  'accord ins' 'ace american insurance c' 'ace financial'
#  'ace financial gro' 'a' 'admiral indemnity c' 'admiral insura'
#  'admiral insurance c' 'aeon risk services northeas'
#  'affinity insurance s' 'aggressive insurance servi'
#  'aggressive insurance service' 'aif- agency ins & fin' 'aig life insuran'
#  'aig specialty insurance c' 'ajg gallager-af' 'allen & asso'
#  'allianz global risks us insura' 'allianz underwriters insurance c'
#  'allied world assurance ' 'allied world insurance c'
#  'allied world specialty insurance c' 'allied world surplus lines ins'
#  'allied world surplus lines insurance c' 'american administrative group'
#  'american affinity' 'american alternative insurance c'
#  'american alternative insurance corpo' 'american auto ins c'
#  'american automobile insurance c' 'american capitol insuran'
#  'american endurance specialty ' 'american family home insurance c'
#  'american family life assurance'
#  'american farmers & ranchers mutual insura' 'american guarantee & lia'
#  'american international specialty lines insur'
#  'american national family of com'
#  'american national property and casualty c'
#  'american pacific life and reti' 'american southern home insurance c'
#  'ameriprise captive insurance c' 'amtrust north a' 'aon affinity se'
#  'aon risk insurance services wes' 'aon risk insurance services west'
#  'aon risk services central' 'aon risk services northea'
#  'aon risk services northeast' 'arch insura' 'arch speciality ins'
#  'argonaut insurance c' 'arthur j. gallagher - ' 'aspen am'
#  'aspen american insurance c' 'aspen specialty insurance c'
#  'associated industries in' 'atlantic specialty insurance c'
#  'automatic data processing insurance agenc' 'axis insurance c'
#  'axis surplus insura' 'baxter and asso' 'bcs insura' 'bcs life insuran'
#  'beazley insurance c' 'benefits technologie'
#  'berkely association services' 'berkley assurance c'
#  'berkley insurance c'
#  'berkley service professionals, a division of berkley managers insurance service'
#  'berkshire ha' 'berkshire hathaway insurers of '
#  'berkshire hathaway speciality insurance c' 'bern ins'
#  'brown & brown program insurance services' 'cals' 'cal'
#  'capitol indemnity corpo' 'capitol specialty insura'
#  'capitol specialty insuranc' 'cbiz insurance services'
#  "certain underwriters at lloyd's " 'cfc underwriting l'
#  'chartis sepcialty insurance c' 'chartis speciality insurance c' 'c'
#  'chubb indemnity insurance c' 'cincinnati casualty c' 'cita insurance ca'
#  'cita lie ins' 'cita life ins' 'clarendon america ins c'
#  'claridge insurance c' 'columbia casualty insura' 'continental assuran'
#  'continental casualty c' 'continental casualty insuran'
#  'continental insurance co' 'corrisk sol' 'coverag'
#  'cpa mutual insurance company of a' 'daniels insuranc'
#  'darwin national assuran' 'darwin select ' 'defender pl' 'diana janeth'
#  'domininion insurance se' 'dominion insurance se' 'donald gaddis co.'
#  'dual insurance c' 'e' 'ehealth ins' 'ehealth insurance service' 'ehealt'
#  'endurance american insurance c' 'endurance american spe'
#  'endurance american specialty '
#  'endurance american specialty insurance c' 'endurance insurance c'
#  'endurance risk solutions assuran' 'epsilon insura'
#  'evanston insurance c' 'everest indemnity insurance c'
#  'everest national insurance c' 'executive risk spec' 'fcci insurance c'
#  'federal insura' 'firemans fund insuran' 'first choice insurance '
#  'first specialty insuranc' 'freedom insurance c' 'gallager af'
#  'gallagher af' 'gallagh' 'general insurance c'
#  'general insurance company of a' 'graphic arts mutual insurance c'
#  'great american al' 'great american alliance insurance c'
#  'great american asurance c' 'great american'
#  'great american fidelity insurance c' 'great american insura'
#  'great midwest ins' 'great midwest life insuran' 'greenwich insurance c'
#  'guardian life insurance co. of a' 'h&w indemnity (spc)'
#  'hanover insurance' 'hartford insurance c' 'hartford life insuran'
#  'hcc specialty ' 'hdi specialty insurance c' 'hiscox insurance compan'
#  'homeland insurance c' 'homeland insurance of ne' 'hometown insurance '
#  'hometown insurance of l' 'houston casua' 'houston casualty c'
#  'hub interna' 'hudson specialty insuran'
#  'icici lombard general insurance company l' 'ihc - specialty benefits'
#  'ihc specailty benefi' 'ihc specialty be' 'illinois national insurance c'
#  'illinois union insura' 'indep. insurance agents of'
#  'indian harbor insurance c' 'insuran' 'insureon (bin insurance holding'
#  'interstate fire and casualty c' 'interweb insuranc'
#  'ironshore indemnity' 'ironshore specialty insurance c'
#  'james river insurance c' 'kind health holdin' 'kind health holding'
#  'kinsale insura' 'knightbrook insurance c' 'landmark american i'
#  'landmark insura' 'lee & mason financial se' 'lexington insurance c'
#  'liberty insurance services corp.' 'liberty insurance underwrite'
#  'libert' 'liber' 'liberty mutual insuran' 'liberty surplus ins'
#  'lighthouse insurance ' 'lincoln national life insuran' 'l'
#  "lloyd's syndicate no" 'lloyds of ' 'lmc insurance & risk management'
#  'lockton com' 'logic insurance se' 'loman-ray insurance'
#  'lyndon southenr insurance c' 'm3 insurance solutions'
#  'markel american insuran' 'markel insurance c' 'm'
#  'marsh & mclennan agen' 'marsh mc' 'marsh risk & insurance c'
#  'marsh risk & insurance se' 'marsh risk an insurance c'
#  'marsh risk and insurance se' 'marsh risk insurance se'
#  'massachusetts bay insurance c' 'maxum indemn' 'maxum insurance c'
#  'mercer co'
#  'mercer consumer, a service of mercer health & benefits administrati'
#  'mercer health & benefits administati'
#  'mercer health & benefits administrati'
#  'mercer health and benefits administratio' 'merchants bonding c'
#  'messer financial' 'mga gal' 'mga insurance se'
#  'mount vernon fire insurance c' 'mt. ' 'naifa professional liability ins'
#  'namic insurance company' 'national association of professional '
#  'national association of professional agent'
#  'national association of professional a' 'national casualty c'
#  'national fire & marine ins' 'national general accident & '
#  'national specialty insurance c' 'national union fire ins co of'
#  'national union fire insurance c' 'national union fire insurance comp'
#  'national union fire insurance company' 'nautilus insurance c'
#  'navigator specialty ins' 'new york life insurance & annui'
#  'newer test c' 'newest test c' 'newport insurance co' 'next ins'
#  'next insurance c' 'next insurance company' 'next insuran'
#  'nfp property & casualty services' 'no carrie' 'nocarri'
#  'ohio national life insurance c' 'old republic insuran' 'o'
#  'pacific casualty c' 'pacific casualty compa' 'pacific indemnity c'
#  'partnerre irela' 'pearl ins' 'peleus insurance c'
#  'penn national mutual ca' 'philadelphia indemnity insura'
#  'philadelphia insurance com' 'pride life insuranc'
#  'protective specialty insurance c' 'pug (previously uninsured '
#  'qbe insurance corpo' 'qbe specialty insurance c' 'qu'
#  'republic franklin insurance c' 'retention alternativ'
#  'risk placement services' 'rockwood pr' 'royal alliance associates'
#  'rt spe' 'ryan turner speciality' 'sanus be' 'scottsdale indemnity c'
#  'scottsdale insuran' 'scottsdale surplus lines i'
#  'security national insurance c' 'sentinel ins ' 'sentry life insuran'
#  'shelter mutual insura' 'sompo interna'
#  'southern farm bureau life insurance c' 'src conner grou'
#  'st paul fire & marine ins c' 'st paul guardian insurance c'
#  'st paul ins' 'st. pau' 'starnet insurance c'
#  'starr indemnity and liability c' 'starr surplus lines insurance c'
#  'stone mountain insurance c' 'sura' 'swiss re corporate sol'
#  'swiss re internat' 'test c' 'texas farm ' 'texas ins prof ser' 't'
#  'the brokera' 'the brokerage inc um' 'the brokerag'
#  'the brokerage will se' 'the brokerage' 'the cincinnati insurance c'
#  'the hanover insurance c' 'the ohio national life insurance c'
#  'the real insuranc' 'the sentinel insurance c'
#  'travelers casualty and surety company of a' 'travelers '
#  'travelers excess and surplus lin' 'travelers indemnity c'
#  'twin city fire insurance c' 'twin city insurance c' 'u.s. ris' 'u'
#  "underwriters at lloyd's " 'underwriters at '
#  'united states liability insurance c' 'united states liability insura'
#  'us liability ins' 'us ri' 'utica mutual insurance c' 'utica na'
#  'utica national insurance' 'valley forge ins' 'viti fin'
#  'wesco insurance c' 'westchester surplus lines ins' 'western'
#  'western world insuran' 'western world insurance c'
#  'westport insurance c' 'westport insurance corpo' 'willis of new yo'
#  'willis of new yor' 'willis of new york' 'willis submission c'
#  'world fianancial gro' 'world financial' 'world financial group'
#  'worldwide brokers and ' 'xl specialty insuran' 'zurich american insuran']
# ['1st community insuranc' '36' '360 co' '360 cov' '360 degree cov' ''
#  'aaa life ins' 'abi administrativ' 'accord' 'ace american insuran'
#  'ace finan' 'ace financial' 'admiral indemni' 'admiral in'
#  'admiral insuran' 'aeon risk services nort' 'affinity insuran'
#  'aggressive insurance s' 'aggressive insurance ser' 'aif- agency ins &'
#  'aig life ins' 'aig specialty insuran' 'ajg gallage' 'allen & '
#  'allianz global risks us in' 'allianz underwriters insuran'
#  'allied world assura' 'allied world insuran'
#  'allied world specialty insuran' 'allied world surplus lines'
#  'allied world surplus lines insuran' 'american administrative g'
#  'american affi' 'american alternative insuran'
#  'american alternative insurance c' 'american auto i'
#  'american automobile insuran' 'american capitol ins'
#  'american endurance specia' 'american family home insuran'
#  'american family life assur' 'american farmers & ranchers mutual in'
#  'american guarantee &' 'american international specialty lines i'
#  'american national family of' 'american national property and casual'
#  'american pacific life and ' 'american southern home insuran'
#  'ameriprise captive insuran' 'amtrust nor' 'aon affinit'
#  'aon risk insurance services' 'aon risk insurance services '
#  'aon risk services cen' 'aon risk services nor' 'aon risk services north'
#  'arch in' 'arch speciality' 'argonaut insuran' 'arthur j. gallaghe'
#  'aspe' 'aspen american insuran' 'aspen specialty insuran'
#  'associated industrie' 'atlantic specialty insuran'
#  'automatic data processing insurance a' 'axis insuran' 'axis surplus in'
#  'baxter and ' 'bcs in' 'bcs life ins' 'beazley insuran'
#  'benefits technol' 'berkely association serv' 'berkley assuran'
#  'berkley insuran'
#  'berkley service professionals, a division of berkley managers insurance ser'
#  'berkshir' 'berkshire hathaway insurers'
#  'berkshire hathaway speciality insuran' 'bern'
#  'brown & brown program insurance serv' 'ca' 'capitol indemnity c'
#  'capitol specialty in' 'capitol specialty insu' 'cbiz insurance serv'
#  'certain underwriters at lloy' 'cfc underwriti'
#  'chartis sepcialty insuran' 'chartis speciality insuran'
#  'chubb indemnity insuran' 'cincinnati casual' 'cita insuranc' 'cita lie'
#  'cita life' 'clarendon america i' 'claridge insuran'
#  'columbia casualty in' 'continental ass' 'continental casual'
#  'continental casualty ins' 'continental insuranc' 'corrisk' 'cov'
#  'cpa mutual insurance company ' 'daniels insu' 'darwin national ass'
#  'darwin sel' 'defende' 'diana ja' 'domininion insuranc'
#  'dominion insuranc' 'donald gaddis' 'dual insuran' 'ehealth'
#  'ehealth insurance ser' 'eh' 'endurance american insuran'
#  'endurance american' 'endurance american specia'
#  'endurance american specialty insuran' 'endurance insuran'
#  'endurance risk solutions ass' 'epsilon in' 'evanston insuran'
#  'everest indemnity insuran' 'everest national insuran' 'executive risk '
#  'fcci insuran' 'federal in' 'firemans fund ins' 'first choice insura'
#  'first specialty insu' 'freedom insuran' 'gallage' 'gallaghe' 'gal'
#  'general insuran' 'general insurance company '
#  'graphic arts mutual insuran' 'great america'
#  'great american alliance insuran' 'great american asuran' 'great amer'
#  'great american fidelity insuran' 'great american in' 'great midwest'
#  'great midwest life ins' 'greenwich insuran'
#  'guardian life insurance co. ' 'h&w indemnity (' 'hanover insur'
#  'hartford insuran' 'hartford life ins' 'hcc specia'
#  'hdi specialty insuran' 'hiscox insurance co' 'homeland insuran'
#  'homeland insurance o' 'hometown insura' 'hometown insurance '
#  'houston c' 'houston casual' 'hub int' 'hudson specialty ins'
#  'icici lombard general insurance compa' 'ihc - specialty bene'
#  'ihc specailty be' 'ihc specialt' 'illinois national insuran'
#  'illinois union in' 'indep. insurance agent' 'indian harbor insuran'
#  'ins' 'insureon (bin insurance hol' 'interstate fire and casual'
#  'interweb insu' 'ironshore indem' 'ironshore specialty insuran'
#  'james river insuran' 'kind health ho' 'kind health hol' 'kinsale in'
#  'knightbrook insuran' 'landmark americ' 'landmark in'
#  'lee & mason financia' 'lexington insuran' 'liberty insurance services c'
#  'liberty insurance underw' 'li' 'l' 'liberty mutual ins'
#  'liberty surplus' 'lighthouse insura' 'lincoln national life ins'
#  "lloyd's syndicat" 'lloyds' 'lmc insurance & risk manage' 'lockton'
#  'logic insuranc' 'loman-ray insur' 'lyndon southenr insuran'
#  'm3 insurance solut' 'markel american ins' 'markel insuran'
#  'marsh & mclennan ' 'mars' 'marsh risk & insuran' 'marsh risk & insuranc'
#  'marsh risk an insuran' 'marsh risk and insuranc' 'marsh risk insuranc'
#  'massachusetts bay insuran' 'maxum in' 'maxum insuran' 'merce'
#  'mercer consumer, a service of mercer health & benefits administ'
#  'mercer health & benefits adminis' 'mercer health & benefits administ'
#  'mercer health and benefits administr' 'merchants bondi' 'messer finan'
#  'mga' 'mga insuranc' 'mount vernon fire insuran'
#  'naifa professional liability' 'namic insurance com'
#  'national association of professio'
#  'national association of professional a'
#  'national association of profession' 'national casual'
#  'national fire & marine' 'national general acciden'
#  'national specialty insuran' 'national union fire ins c'
#  'national union fire insuran' 'national union fire insurance '
#  'national union fire insurance com' 'nautilus insuran'
#  'navigator specialty' 'new york life insurance & a' 'newer te'
#  'newest te' 'newport insuranc' 'next' 'next insuran' 'next insurance com'
#  'next ins' 'nfp property & casualty serv' 'no ca' 'noc'
#  'ohio national life insuran' 'old republic ins' 'pacific casual'
#  'pacific casualty c' 'pacific indemni' 'partnerre i' 'pearl'
#  'peleus insuran' 'penn national mutua' 'philadelphia indemnity in'
#  'philadelphia insurance' 'pride life insu' 'protective specialty insuran'
#  'pug (previously uninsu' 'qbe insurance c' 'qbe specialty insuran'
#  'republic franklin insuran' 'retention altern' 'risk placement serv'
#  'rockwoo' 'royal alliance associ' 'rt' 'ryan turner specia' 'sanu'
#  'scottsdale indemni' 'scottsdale ins' 'scottsdale surplus lin'
#  'security national insuran' 'sentinel ' 'sentry life ins'
#  'shelter mutual in' 'sompo int' 'southern farm bureau life insuran'
#  'src conner ' 'st paul fire & marine i' 'st paul guardian insuran'
#  'st paul' 'st.' 'starnet insuran' 'starr indemnity and liabili'
#  'starr surplus lines insuran' 'stone mountain insuran'
#  'swiss re corporate' 'swiss re inte' 'te' 'texas f' 'texas ins prof'
#  'the bro' 'the brokerage in' 'the brok' 'the brokerage wil' 'the broke'
#  'the cincinnati insuran' 'the hanover insuran'
#  'the ohio national life insuran' 'the real insu' 'the sentinel insuran'
#  'travelers casualty and surety company ' 'travel'
#  'travelers excess and surplus' 'travelers indemni'
#  'twin city fire insuran' 'twin city insuran' 'u.s.'
#  'underwriters at lloy' 'underwriters' 'united states liability insuran'
#  'united states liability in' 'us liability' 'u' 'utica mutual insuran'
#  'utic' 'utica national insur' 'valley forge' 'viti' 'wesco insuran'
#  'westchester surplus lines' 'wes' 'western world ins'
#  'western world insuran' 'westport insuran' 'westport insurance c'
#  'willis of ne' 'willis of new' 'willis of new ' 'willis submissi'
#  'world fianancial' 'world finan' 'world financial g' 'worldwide brokers '
#  'xl specialty ins' 'zurich american ins']
# ['1st community ins' '' '3' '36' '360 degre' 'aaa lif' 'abi administ' 'a'
#  'ace american in' 'ace ' 'ace fina' 'admiral in' 'admir'
#  'aeon risk services' 'affinity in' 'aggressive insura'
#  'aggressive insuranc' 'aif- agency ' 'aig lif' 'aig specialty in'
#  'ajg ga' 'all' 'allianz global risks ' 'allianz underwriters in'
#  'allied world a' 'allied world in' 'allied world specialty in'
#  'allied world surplus ' 'allied world surplus lines in'
#  'american administrat' 'american' 'american alternative in'
#  'american alternative insura' 'american a' 'american automobile in'
#  'american capito' 'american endurance s' 'american family home in'
#  'american family life ' 'american farmers & ranchers mutu'
#  'american guaran' 'american international specialty li'
#  'american national fami' 'american national property and c'
#  'american pacific life' 'american southern home in'
#  'ameriprise captive in' 'amtrus' 'aon af' 'aon risk insurance ser'
#  'aon risk insurance serv' 'aon risk service' 'aon risk services ' 'ar'
#  'arch speci' 'argonaut in' 'arthur j. gal' 'asp' 'aspen american in'
#  'aspen specialty in' 'associated indu' 'atlantic specialty in'
#  'automatic data processing insura' 'axis in' 'axis surpl' 'baxter' 'b'
#  'bcs lif' 'beazley in' 'benefits te' 'berkely association' 'berkley as'
#  'berkley in'
#  'berkley service professionals, a division of berkley managers insuranc'
#  'ber' 'berkshire hathaway ins' 'berkshire hathaway speciality in'
#  'brown & brown program insurance' 'capitol indemn' 'capitol special'
#  'capitol specialty' 'cbiz insurance' 'certain underwriters at'
#  'cfc under' 'chartis sepcialty in' 'chartis speciality in'
#  'chubb indemnity in' 'cincinnati c' 'cita ins' 'cit' 'cita'
#  'clarendon amer' 'claridge in' 'columbia casual' 'continenta'
#  'continental c' 'continental casualt' 'continental ins' 'co' 'c'
#  'cpa mutual insurance com' 'daniels' 'darwin nationa' 'darwi' 'de' 'dia'
#  'domininion ins' 'dominion ins' 'donald g' 'dual in' 'eh'
#  'ehealth insuranc' 'endurance american in' 'endurance ame'
#  'endurance american s' 'endurance american specialty in' 'endurance in'
#  'endurance risk solution' 'epsil' 'evanston in' 'everest indemnity in'
#  'everest national in' 'executive ' 'fcci in' 'feder' 'firemans fun'
#  'first choice i' 'first specialty' 'freedom in' 'ga' 'gal' 'g'
#  'general in' 'general insurance com' 'graphic arts mutual in' 'great am'
#  'great american alliance in' 'great american a' 'great'
#  'great american fidelity in' 'great americ' 'great mi'
#  'great midwest lif' 'greenwich in' 'guardian life insurance' 'h&w indemn'
#  'hanover ' 'hartford in' 'hartford lif' 'hcc s' 'hdi specialty in'
#  'hiscox insuran' 'homeland in' 'homeland insura' 'hometown i'
#  'hometown insur' 'hous' 'houston c' 'hu' 'hudson specialt'
#  'icici lombard general insurance ' 'ihc - specialty' 'ihc specail'
#  'ihc spe' 'illinois national in' 'illinois uni' 'indep. insurance '
#  'indian harbor in' 'i' 'insureon (bin insuranc' 'interstate fire and c'
#  'interweb' 'ironshore ' 'ironshore specialty in' 'james river in'
#  'kind heal' 'kind healt' 'kinsa' 'knightbrook in' 'landmark a' 'landma'
#  'lee & mason fin' 'lexington in' 'liberty insurance servi'
#  'liberty insurance u' 'liberty mutua' 'liberty su' 'lighthouse i'
#  'lincoln national lif' "lloyd's syn" 'l' 'lmc insurance & risk m' 'lo'
#  'logic ins' 'loman-ray ' 'lyndon southenr in' 'm3 insurance '
#  'markel america' 'markel in' 'marsh & mcle' 'mar' 'marsh risk & in'
#  'marsh risk & ins' 'marsh risk an in' 'marsh risk and ins'
#  'marsh risk ins' 'massachusetts bay in' 'max' 'maxum in'
#  'mercer consumer, a service of mercer health & benefits adm'
#  'mercer health & benefits ad' 'mercer health & benefits adm'
#  'mercer health and benefits admi' 'merchants ' 'messer ' 'm' 'mga ins'
#  'mount vernon fire in' 'naifa professional liab' 'namic insuranc'
#  'national association of prof' 'national association of professio'
#  'national association of profe' 'national c' 'national fire & m'
#  'national general ac' 'national specialty in' 'national union fire '
#  'national union fire in' 'national union fire insur'
#  'national union fire insuranc' 'nautilus in' 'navigator spec'
#  'new york life insuranc' 'new' 'newe' 'newport ins' 'nex' 'next in'
#  'next insuranc' 'nfp property & casualty' 'n' 'ohio national life in'
#  'old republi' 'pacific c' 'pacific casua' 'pacific in' 'partne'
#  'peleus in' 'penn national ' 'philadelphia indemni' 'philadelphia insu'
#  'pride life' 'protective specialty in' 'pug (previously u' 'qbe insura'
#  'qbe specialty in' 'republic franklin in' 'retention a' 'risk placement'
#  'ro' 'royal alliance a' 'ryan turner s' 'san' 'scottsdale in' 'scottsdal'
#  'scottsdale surplu' 'security national in' 'sent' 'sentry lif'
#  'shelter mutu' 'somp' 'southern farm bureau life in' 'src co'
#  'st paul fire & mar' 'st paul guardian in' 'st' 's' 'starnet in'
#  'starr indemnity and li' 'starr surplus lines in' 'stone mountain in'
#  'swiss re corp' 'swiss re' 'te' 'texas ins' 'th' 'the brokera' 'the'
#  'the brokerag' 'the ' 'the cincinnati in' 'the hanover in'
#  'the ohio national life in' 'the real' 'the sentinel in'
#  'travelers casualty and surety com' 't' 'travelers excess and su'
#  'travelers in' 'twin city fire in' 'twin city in' 'u.s' 'underwriters at'
#  'underwr' 'united states liability in' 'united states liabili' 'us liab'
#  'utica mutual in' 'uti' 'utica national ' 'valley ' 'vit' 'wesco in'
#  'westchester surplus ' 'w' 'western worl' 'western world in'
#  'westport in' 'westport insura' 'willis ' 'willis o' 'willis of'
#  'willis sub' 'world fiana' 'world ' 'world financ' 'worldwide bro'
#  'xl specialt' 'zurich america']
# ['1st communi' '' '360' 'a' 'abi ad' 'ace ameri' 'ac' 'admi'
#  'aeon risk se' 'affin' 'aggressive ' 'aggressive in' 'aif- a'
#  'aig specia' 'allianz global ' 'allianz underwrit' 'allied w' 'allied wo'
#  'allied world specia' 'allied world su' 'allied world surplus li'
#  'american admin' 'am' 'american alternat' 'american alternative ' 'amer'
#  'american automob' 'american ' 'american endur' 'american family h'
#  'american family' 'american farmers & rancher'
#  'american international specia' 'american nationa'
#  'american national property' 'american pacifi' 'american southern h'
#  'ameriprise capt' 'aon risk insuran' 'aon risk insuranc' 'aon risk s'
#  'aon risk ser' 'arch' 'argon' 'arthur ' 'aspen ameri' 'aspen specia'
#  'associate' 'atlantic specia' 'automatic data processing ' 'axis' 'b'
#  'beaz' 'benef' 'berkely assoc' 'berk'
#  'berkley service professionals, a division of berkley managers in'
#  'berkshire hathaw' 'berkshire hathaway special'
#  'brown & brown program ins' 'capitol ' 'capitol s' 'capitol spe'
#  'cbiz ins' 'certain underwrit' 'cfc' 'chartis sepcia' 'chartis special'
#  'chubb indemn' 'cincin' 'ci' 'clarendo' 'clari' 'columbia ' 'cont'
#  'contine' 'continental c' 'continent' 'cpa mutual insuran' 'd' 'darwin n'
#  'darw' 'dominini' 'domini' 'do' 'ehealth in' 'endurance ameri' 'enduran'
#  'endurance amer' 'endurance american specia' 'endura' 'endurance risk so'
#  'epsi' 'evans' 'everest indemn' 'everest natio' 'exec' 'f' 'fede'
#  'firema' 'first ch' 'first spe' 'free' 'gene' 'general insuran'
#  'graphic arts mut' 'gr' 'great american allia' 'great amer' 'grea'
#  'great american fidel' 'great ' 'great midwe' 'greenw'
#  'guardian life ins' 'h&w ' 'ha' 'hartf' 'hartfo' 'hcc ' 'hdi specia'
#  'hiscox i' 'homel' 'homeland ' 'home' 'hometown' 'ho' 'hou' 'hudson sp'
#  'icici lombard general insu' 'ihc - spe' 'ihc s' 'i' 'illinois natio'
#  'illino' 'indep. insu' 'indian har' 'insureon (bin in' 'interstate fire'
#  'in' 'iron' 'ironshore specia' 'james ri' 'kin' 'kind' 'kins' 'knightbr'
#  'land' 'lee & mas' 'lexing' 'liberty insurance' 'liberty insur' 'liberty'
#  'libe' 'lighth' 'lincoln nation' 'lloyd' 'lmc insurance & ' 'log' 'loma'
#  'lyndon south' 'm3 insu' 'markel a' 'mar' 'marsh ' 'marsh ris'
#  'marsh risk' 'marsh risk a' 'marsh ri' 'massachusetts ' 'ma'
#  'mercer consumer, a service of mercer health & benefi'
#  'mercer health & benef' 'mercer health & benefi'
#  'mercer health and benefit' 'merc' 'm' 'mount vernon f'
#  'naifa professiona' 'namic in' 'national association o'
#  'national association of pro' 'national association of' 'nati'
#  'national fi' 'national gene' 'national specia' 'national union'
#  'national union f' 'national union fire' 'national union fire in' 'nauti'
#  'navigato' 'new york life in' 'ne' 'newpo' 'n' 'next in'
#  'nfp property & ca' 'ohio national l' 'old r' 'pac' 'pacific' 'paci'
#  'pel' 'penn nat' 'philadelphia i' 'philadelphi' 'prid'
#  'protective specia' 'pug (previo' 'qbe ' 'qbe specia' 'republic frank'
#  'reten' 'risk pla' 'royal alli' 'ryan tu' 'scottsd' 'sco' 'scottsdale '
#  'security natio' 'se' 'sent' 'shelte' 'so' 'southern farm bureau l'
#  'st paul fire' 'st paul guard' 'star' 'starr indemnity '
#  'starr surplus li' 'stone mount' 'swiss r' 'sw' 'tex' 'the b' 'the br'
#  'th' 'the cincinn' 'the hano' 'the ohio national l' 'the senti'
#  'travelers casualty and sure' 'travelers excess ' 'travel' 'twin city f'
#  'twin c' 'underwrit' 'u' 'united states liabil' 'united states l'
#  'utica mut' 'utica nat' 'v' 'we' 'westchester su' 'wester' 'western wo'
#  'westp' 'westport ' 'w' 'wi' 'wil' 'will' 'world' 'world ' 'worldwi'
#  'xl sp' 'zurich a']
# ['1st ' '' 'abi a' 'ac' 'a' 'aeon ' 'aff' 'aggr' 'aggres' 'aif- ' 'aig'
#  'allianz ' 'allianz un' 'al' 'allied world' 'allied w' 'allied world sur'
#  'america' 'american a' 'american alter' 'american ' 'am' 'american f'
#  'american' 'american farmers & ' 'american international'
#  'american national p' 'american sou' 'ameripri' 'aon risk ' 'aon risk i'
#  'aon' 'aon r' 'arg' 'aspe' 'aspen' 'as' 'atlantic' 'automatic data proc'
#  'b' 'ben' 'berkel'
#  'berkley service professionals, a division of berkley mana' 'berkshire'
#  'berkshire hathaway ' 'brown & brown prog' 'c' 'ca' 'capi' 'certain un'
#  'chartis' 'chartis ' 'chubb' 'cinci' 'cla' 'co' 'contin' 'cpa mutual '
#  'd' 'domin' 'ehe' 'enduranc' 'enduran' 'endurance american' 'endur'
#  'endurance ' 'e' 'eva' 'everest' 'everes' 'f' 'firem' 'fi' 'g' 'general '
#  'graphic a' 'great america' 'gre' 'great' 'grea' 'green' 'guardian l' 'h'
#  'har' 'hartf' 'hdi' 'hom' 'ho' 'hu' 'icici lombard gener' 'ih' 'ihc'
#  'illinoi' 'illin' 'inde' 'ind' 'insureon ' 'intersta' 'i' 'ironshore' 'j'
#  'k' 'l' 'le' 'lexin' 'liberty in' 'libert' 'light' 'lincoln' 'llo'
#  'lmc insur' 'lyndo' 'm' 'marsh' 'ma' 'mar' 'massach'
#  'mercer consumer, a service of mercer health &' 'mercer health '
#  'mercer health &' 'mercer health and ' 'mount v' 'naifa prof' 'n'
#  'national associ' 'national association' 'national associa' 'nati'
#  'nation' 'national' 'nationa' 'national ' 'national uni'
#  'national union ' 'nau' 'new york ' 'new' 'nfp proper' 'ohio nat' 'old'
#  'p' 'philade' 'phil' 'protective' 'pug ' 'q' 'qbe' 'republi' 'ret' 'r'
#  'roy' 'scot' 'securit' 's' 'shelt' 'southern farm b' 'st pa' 'st pau'
#  'starr ind' 'starr sur' 'ston' 'the' 'the b' 'the ' 't' 'the ohio nat'
#  'th' 'travelers casualty a' 'travelers ' 'trave' 'twin' 'twin ' 'un'
#  'united states' 'united s' 'ut' 'westche' 'weste' 'wes' 'we' 'w' 'wor'
#  'world' 'xl ' 'z']
# ['' 'ab' 'ae' 'aggr' 'ai' 'al' 'alli' 'allied w' 'americ' 'am' 'a'
#  'american fa' 'american inter' 'american na' 'amer' 'ao' 'as'
#  'automatic d' 'berk' 'berkley service professionals, a division of berk'
#  'b' 'berkshire h' 'brown & br' 'ce' 'charti' 'ch' 'ci' 'cont' 'cpa' 'do'
#  'endura' 'endurance ' 'en' 'everes' 'ever' 'fi' 'g' 'great' 'gr' 'gu'
#  'ha' 'icici lomba' 'illino' 'il' 'i' 'le' 'li' 'libe' 'lincol' 'l' 'ly'
#  'ma' 'massac' 'mercer consumer, a service of mercer ' 'mercer' 'mercer '
#  'mercer hea' 'mount ' 'na' 'nationa' 'national ass' 'national' 'nati'
#  'nation' 'n' 'nf' 'philad' 'pr' 'republ' 'securi' 'sh' 'souther' 'st'
#  'st p' 's' 'th' 'the ' 'travelers ca' 'tr' 'tw' 'unite' 'westch' 'we'
#  'wo']
# ['' 'allied ' 'ame' 'am' 'ameri' 'au'
#  'berkley service professionals, a divisio' 'be' 'b' 'cha' 'end' 'e' 'eve'
#  'g' 'ic' 'ill' 'lin' 'mas' 'mercer consumer, a service o' 'mer' 'merce'
#  'm' 'mou' 'natio' 'nat' 'nationa' 'phi' 'rep' 'sec' 'south' 'tra' 'u'
#  'wes']
# ['' 'alli' 'berkley service professionals,' 'mercer consumer, a' 'nati']
# ['' 'berkley service pro' 'mercer ']

# %%
analysis_df_tail = pd.DataFrame(analysis_tail)

# %%
analysis_df_tail
# Out:
#     number_names  avg_pct_len
# 0            371        100.0
# 1            371         95.0
# 2            368         90.0
# 3            358         85.0
# 4            345         80.0
# 5            330         76.0
# 6            270         71.0
# 7            185         66.0
# 8             84         61.0
# 9             33         56.0
# 10             5         51.0
# 11             3         46.0

# %%
analysis_df_tail.plot(x='avg_pct_len', y='number_names')

# %%
def names_deconstructor(names_df, head = False):
    """
    This function takes in a dataframe with the first column 
    as a list of names or different strings and deconstructs
    them one character at a time. It returns a dataframe and
    a plot of how the deconstruction went.
    
    This should be used to find duplicates or similar words
    
    It will also accept a list, series or dict if passed and 
    turn that into a dataframe.
    
    The head is set to false by default because the analysis 
    begins at the tail end of a word. In order to start at 
    the beginning of a word please set it to true.
    
    This function requires that the user have Pandas and 
    Matplotlib.
    
    """
#     handle other types than dataframe
    if type(names_df) != 'pandas.core.frame.DataFrame':
    
        names_df = pd.DataFrame(names_df)
    
    names_df['NAME'] = names_df.iloc[:,0]
    
#     setup variables and columns for analysis
    names_df['LENGTH'] = names_df['NAME'].apply(lambda x: len(x))
    
    names_df['SUB_LENGTH'] = names_df['NAME'].apply(lambda x: len(x))
    
    names_df['PERCENT_LENGTH'] = names_df['LENGTH'].apply(lambda x: round(100*x/x))
    
    analysis = {'number_names': [len(names_df['NAME'].unique())], 'avg_pct_len': [100]}
    
    avg_pct_min = min(analysis['avg_pct_len'])
    
    substring = 1
    
#     start of analysis of dataframe
    while avg_pct_min >= 50:

#         this is what chops off the words 
        names_df['NAME'] = names_df['NAME'].apply(lambda x: x[(substring):])
        
#         this handles the length values
        names_df['SUB_LENGTH'] = names_df['LENGTH'].apply(lambda x: (x-substring))
        
        names_df['PERCENT_LENGTH'] = 100*(names_df['SUB_LENGTH']/names_df['LENGTH'])
        
#         these two lines capture the values we actually care about
        analysis['number_names'].append(len(names_df['NAME'].unique()))
        
        analysis['avg_pct_len'].append(round(carrier_df['PERCENT_LENGTH'].mean()))

#         the below line is for debugging
#         print(names_df['COMPANYNAME'].unique())


        substring += 1
    
#        this determines whether we should keep looping
        avg_pct_min = min(analysis['avg_pct_len'])
    
#     now we are outside the loop
    analysis_df = pd.DataFrame(analysis)
    return analysis_df

    analysis_df.plot(x='avg_pct_len', y='number_names')

# %%
carrier_df = pd.read_csv('INSURANCE_CARRIERNAMES.csv')

# %%
carrier_df.rename({1:'NAME'}, axis='columns')
# Out:
#   File "<ipython-input-28-fbd2243620cb>", line 1
#     carrier_df.rename({[:,1]:'NAME'}, axis='columns')
#                         ^
# SyntaxError: invalid syntax
